# %% [markdown]
# # Detección de tweets meteorológicos con Bag of Words

# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Cargo la base de datos clasificada y genero las variables de importancia

# %%
TW = pd.read_csv('base_corr.csv')
MSJ = TW['Twit']
TAG = TW['Tag']
NUM = TW['Num']

# %% [markdown]
# ### Defino una variable cantidad que tiene la cantidad de tw de cada tipo

# %%
cant = [len (np.array(TAG) [np.where(TAG == 0)]) , len (np.array(TAG) [np.where(TAG == 1)])]

# %% [markdown]
# #### Elimino las cosas innecesarias de msj

# %%
def normalizacion(mensaje):
    
    mensaje = list(mensaje)
    lenght = len(mensaje)
    
    lista_ascii = [['\\xe1', '\\xe9', '\\xed', '\\xf3', '\\xfa', '\\xf1', '\\xd1', '\\xc1','\\xc9', '\\xcd', '\\xd3', 
                 '\\xda', '\\xa1', '\\xbf', '\\xdc', '\\xfc', '\\xb4', '\\xba', '\\xaa', '\\xb7','\\xc7','\\xe7',
                 '\\xa8', '\\xb0C', '\\n', '\\xb0c', '\\xbb', 'xb0', '\\ufe0f'],
                   ['a', 'e', 'i', 'o', 'u', 'ñ', 'Ñ', 'A', 'E', 'I', 'O', 'U', '', '', 'Ü', 'ü', '', 
                           ' ', '', '','Ç','ç','', ' ', ' ', ' ', ' ', ' ', ' ']]
    lista_simb = ['!','\'', '\"', "|", '$', "%", "&", "(", ")", "=", "?", "+",'/', ";", "_", "-", "1","2",
                  "3","4","5","6","7","8","9","0", '*',',', '.', ':', '#']
    
    ign_palabras = ['mbar','cdu','s','la','lo','st','que','este', 'me','t','p','el','weathercloud','en','h',
                    'temp','hpa','km','mm',"su","vos",'que',"re","xq","le","te","tu","soy","sos","mi","da","o",
                    "x","les","me","d","q", "como", "lo", "los", "mi", "son", "a", "el", 
                    "un","la", "una","en","por","para", 'las',"ante", "al", 'me',"rt", "del", "y", "se", "de",
                    "que", "sus", "ha", "es", "con", "esta"]
    
    for i in range(lenght):
        
        ## Convierto mayúsculas en minúsculas
        mensaje[i] = mensaje[i].lower()
        
        ## Saco las menciones y otras cosas
        txt = mensaje[i].split()
        
        for j in range(len(txt)):
            if ('@' in txt[j]) and ('RELAMPAGO2018' not in txt[j]) and ('RELAMPAGO_edu' not in txt[j]) or ('jaj' in txt[j]) or ('https' in txt[j]): txt[j]=''
        
        mensaje[i] = " ".join(txt)
        
        ## Reemplazo símbolos
        for h in range(len(lista_simb)):
            mensaje[i] = mensaje[i].replace(lista_simb[h], ' ')
        
        
        for j in mensaje[i].split():
            if str(j).isascii()==False:
                mensaje[i] = mensaje[i].replace(str(j), '')
        
        ## Convierto el msj a ASCII, reemplazo los errores de decodificación y agrego un espacio antes de cada decodificación
        mensaje[i] = mensaje[i].encode('unicode-escape').decode('ASCII')+" "     

              
        
        for k in range(len(lista_ascii[0])):
            mensaje[i] = mensaje[i].replace(lista_ascii[0][k], lista_ascii[1][k])

        
        mensaje[i] = mensaje[i].replace('\\', ' \\')
        
        for j in range(len(ign_palabras)):
            mensaje[i] = mensaje[i].replace(" "+ign_palabras[j]+" ", ' ')
        
    return(mensaje)
msj = normalizacion(MSJ)
msj
# Out:
# ['esta lloviendo ',
#  'quiero ir centro  pero seguro llueve  ',
#  ' si  llueve mucho     ',
#  ' si llueve hago  ',
#  'hasta  voy seguir teniendo miedo tormentas   ',
#  '  climarafaela          hum        bar          lluvia      viento      sso  ',
#  ' sea  sea   no hay plata  ahora llueve   cambia    estudiar igual ',
#  'llueve no tengo internet   espera tremenda tarde ',
#  'que linda noche lluvia  ',
#  ' mucho calor  previo lluvias  ',
#  'me gusta cuando llueve porque parece estan fritando empanadas  puesgorda  ',
#  'noviembre sin ti sentir lluvia dice llorando todo   ',
#  '  agvnet          hum        bar         lluvia    viento       ',
#  'con lluvia dieron ganas cucharear    ',
#  'y largo lluvia  ',
#  'que hermosa tormenta ',
#  ' dan lluvia  ',
#  'aseguran hay stock suficiente bengalas combatir tormentas  ',
#  ' final     cervezas amigos  estuve novio  comi milanesa napolitana   agua hirviendo estoy dormirme  limpias lluvia fondo gato lado  siento  realizada  ',
#  'llueve pq sebastian levanto  ',
#  ' horrible todo  eso llueve  ',
#  ' padre dice ahora van tener poner jugar  yo mientras miro si forma tormenta no  ',
#  'buena  pasaba clima  donde salio lluvia  ',
#  'que onda   llueve  sale sol  llueve  sale sol  tiempo  mas loco yo  ',
#  'lo hermoso  lluvia ',
#  'que  ver otros humanos bicicleta buscando refugio plena tormenta    poca alma bicicletera ',
#  'mi plan dormirme escuchando temas fasciolo ruido lluvia fondo haciendo cucharita gata ',
#  '  agvnet          hum        bar          lluvia    viento     ne  ',
#  'como hace mambear lluvia ',
#  ' venga tormenta dure hasta   ',
#  ' villamaria       hs        min              max                hum      viento      ene  pres       lluvia     ',
#  ' sin dudas usted gobernador querido mejor piloto tormentas     ',
#  'en santa fe llueve  ',
#  'adivinen quien    gracias tormenta ',
#  'me gustado        temporada     acerca tormenta    fortnite  battle royale   ',
#  ' despierto siesta    lluvia quien no duerme   igual hubiera estado  piola si  siesta juntos ahre ',
#  'sos   abran paraguas lluvia datos  ',
#  'netflix   lluvia   perfeccion ',
#  ' aaaaay si boludo tormenta horrible ',
#  'me  lluvia ',
#  ' pusiera mimosa    lluvia pone  gorda  ',
#  'que hermosa  ',
#  'vieron  hay gente estudiando tormentas  bueno  creo  tesis ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'no   pero yo amo dormir lluvia man ',
#  '  agvnet          hum        bar          lluvia    viento     ne  ',
#  'que lluvia pase largooooo  quiero salir manga forros ',
#  'se  tormenta rato otro ',
#  'salir patio escuchar truenos dolby surround      ',
#  'lea  anuncian hasta         lluvias entre  fin   advierten   alto impacto          lluvioso   informe especial provincia    ',
#  'encima lindo andar bajo lluvia  feo calor departamento  ',
#  'datos actuales  santafe barrio candioti norte                          lluvia hoy     ',
#  'uno placeres vida    dormir mientras  ',
#  'hay dormir nomas dice lluvia ',
#  '  video otro tema  porque depende complejidad quiera darle archivo  si  fotos si videos   paso data porque estoy bajo tormenta lpm corta luz cada rato     ',
#  ' uno   cuando wos   cacha   trueno  etc  estaban quinto dtoke ya estaban red bulls inter  bestia  ',
#  'que ganas hacer cucharita wacho lluvia ',
#  'ya sabemos llueve  manga forros ',
#  're xxl lluvia ',
#  'venia gym plena tormenta relajada  cruza hombre dice  corre vienen piedras  cai  ser posible  correr  ',
#  'por fin lluvia hdp ',
#  'tengo ganas salir bicicletear pero viendo fotos  piedras lluvia dio miedo  culpa jeje ahre ',
#  'dormi lindo che   lluvia   ',
#  'el miedo agarre tormentas noche  ',
#  'vete  tormenta  ',
#  'y  tan ansiada lluvia  ',
#  'alguien  escuchando esos truenos  ',
#  'se ve tormenta fue copada porque tiro  locoooooo ',
#  'a hora ir trabajar  llueve locos camilo aldao  ',
#  'mi viejo cae rayo corta luz ',
#  'haganse favor salir mirar cielo  belleza  casi no ve lluvia estrellas  pero igual cielo lleno ',
#  'los   ',
#  'ancohe  rayo primero  fue oigan muchaho ecucharon rempalago    tengo mente matada ya ',
#  'se larga lluvia  fijar tuit  ',
#  'no  lluvia no motiva nada estudiar  solo quiero dormir ',
#  'estamos  nos chupa huevo otro  donde  nos importa cagarnos esfuerzo hacen  persona nos chupa huevo  sienta  si total  yo estoy bien  resto    parta rayo ',
#  'si llueve ya saben porque  estoy yendo colegio ',
#  'dato lluvia  gualeguay    ',
#  ' ssssshhh deja lluvia tranquila vamos dormir siesta  ',
#  'ta desmayarse lluvia ',
#  'amo ver   canchas lluvia admirable ver  tanta lluvia algunos campos  impecables ',
#  'como no cae rayo cabeza concha madre  ',
#  ' imagen satelital   muestra gran frente tormenta abarca sur santa fe  provincia entre rios noreste provincia buenos aires   clima despejado resto zonas productoras          ',
#  'ya veo va largar llover cuando salga casa cuando volviendo  porque lluvia  ',
#  '  agvnet          hum        bar          lluvia    viento      n  ',
#  'que ganas estar vida viendo peliculas mientras escuchando llueve ',
#  'ay lluvia no quiere parar che  ',
#  'ke lluvia culiadaw ',
#  'un hermoso  hoy  ay   bello  hoy   desatar nuestra tormenta va tronar dolor  ',
#  'maldigo veredas hechas mierdas momentos lluvia  ',
#  ' estamos brasil  llueve calor    grados sol    ',
#  'para anduve klx ahora tengo ganas prenderla fuego tornado ',
#  '  seguro  tormenta     ',
#  'lluvia calcada concha madre  ',
#  'pedido solidario afectados lluvias  ',
#  ' porque rato llega tormenta facha    ',
#  'quiero escuchar tormenta abrazada ',
#  'domingo lluvia    arranque lunes media hora  ya fue todo  ',
#  'si lluvia llega hasta   voy limitarme vivir ',
#  'tremenda tormenta madrugada ahora sol parte tierra  esto san luis ',
#  ' estar yendo buscar ropa promo pero estoy caminando bajo lluvia   ',
#  'trueno v      fast furious   ',
#  'si puede jugar  hubo ya final lluvia esa cancha  dudas recuerdo quien fue     finalcopalibertadores  bocavsriver  conmebollibertadores   estudiofutbol   lamejorfinalensc  ',
#  'si llueve ahora menos espero  nublado  no aguanto  ',
#  '          mtvemabiggestfansbts ',
#  ' lluvia   san idiota  confirmado   jacques cousteau era   ',
#  'queria ir pileta  llueve  empece ver serie  corta luz ',
#  '   lluvia ni tiempo nada larga todo nomas ',
#  'quiero alguien pasar  lluvia ',
#  'chica tormenta ',
#  'lluvia vida amo todo   gracias mundo ',
#  'que linda  ',
#  '  encima llueve balde  ',
#  'lo  voy ver    tormenta  viniendo ',
#  'de nuevo  lloviendo  siempre arruinando mis planes lluvia mierda ',
#  'rayos  ',
#  'en vida real tengo miedo truenos   estoy    ',
#  'le puli rayos todo  bastante turra ',
#  'dormir  maravilla ',
#  'llueve  gano belgrano   ',
#  'como loco si llueve ',
#  'llueve   baradel tigre asamblea suteba  espero tenga salir haciendo perrito      encima va tener      ',
#  'encima cuando quiero llueva temporada escuela no llueve  alta leche  ',
#  'las intensas lluvias generaron creciente casi siete metros  san antonio agua ingresa mucha fuerza cauce serranos  luego varios  lluvia afectan   recomienda acatar  defensa civil  no intentar   ',
#  ' hermoso dormir bajo lluvia ahre enfermaba ',
#  '  climarafaela          hum        bar         lluvia       viento      so  ',
#  'los truenos estan dando alto miedo caen cercaaaa ',
#  'quien necesita chongo clima  si tengo gato tiene miedo tormenta  entonces acuesta encima  ',
#  '            marina   especial  hay truenos lluvia  sol todo junto mismo tiempo  hermoso verdad   feliz atardecer noche todos ustedes     ',
#  'no  lluvia si no pisas    baldosas flojas    ',
#  ' estoy esperando lluvia    ',
#  'me dan miedo tormentas  cuando corta luz    ',
#  'vieron  hay familias ponen contentas cuando gana copa equipo futbol  bueno  casa andan  contentos cuando llueve  ',
#  '   intensas lluvias  quedaron barrancas diamante      no dice diario      abandono proyecto estabilizacion barrancas  solo ejecuto zona puerto ultramar  ',
#  'llueve poqui ',
#  'verlo agusin anoche llegar mojado despeinado lluvia hizo cayeran  ',
#  '     cuando    lluvia ',
#  'mirar cielo insistencia suficiente primer rayo gran tormenta impacte tus ojos  ',
#  'lluvia hasta  ',
#  'no hay mirar  cuando llueve estando casa  ',
#  'que hermosa tormenta     ',
#  'esa lluvia pa dormir  ',
#  ' ojo   avisa   luis severa tormenta granizo     mts alrura sobre ruta   atencion puede llegar ciudad hacer  si sigue  ',
#  '  mal amiga flashe lluvia ',
#  'encima llueve estoy pata  embole   ',
#  'desenchufen abuelo hay tormenta  ',
#  'esta lluvia ideal cenar unos fideo salsa  ',
#  'como llueve  orgazmo escuchar sentir esto  ',
#  ' esa calle traumo chica  lluvia sorry ',
#  'me  ir clases pum  tormenta jsksjsj saludos desde cama  ',
#  'la lluvia pa cucharear ',
#  'real estoy entre mirar  serie dormir  seguir pintando  ',
#  'me agarro toda lluvia bici lpm ',
#  'hoy hace       tipo      habia sido expulsado secundaria haber hecho caricatura profesor  tuvo irse otro pais conseguir titulo  estaba haciendo unos experimentos cuando accidentalmente  rayos    ndchances ',
#  'el olor lluvia  ',
#  ' vas mojarte lluvia  ',
#  '  tormentas fuertes   zonas  catamarca  oeste santiago estero   ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'tengo rendir final  todoooo inundado  suerte manejo regalo  ',
#  'con lluvia  estar durmiendo  pero estoy particular ',
#  ' agvnet          hum        bar         lluvia      viento       ',
#  'se ve algunos accionistas  comieron viaje lluvia inversiones  mejor equipo      no vamos controlamos inflacion  etc   problema gran parte nuestra deuda    moneda maneja gran titiritero   ',
#  '   va arriba tormenta  no asustes   ',
#  ' superliga  patronato ruda bajo agua  mismas estuvieron empate  union    abril  hoy  bajo lluvia ingreso vestuario     ',
#  'no trabajo llueve  trabajo hay sol espectacular ir pile  bien vida   ',
#  'lluvia matessss  mejor   ',
#  ' voy madurar dejar tenerle miedo tormentas  hola insomio  ',
#  'que linda lluvia  estoy esperando parta rayo ',
#  'hernan  hacer algo amo amigo hable  pa activarmelos  pero llueve bocha  ',
#  'tremenda lluvia estar acostada pero no   estoy esc no quedarme libre ',
#  'lluvia orrrrto ',
#  'que lluvia hdp ',
#  'linda lluvia  viene chanta canchitas  ',
#  'vamos hoy   ',
#  'que tormenta orto necesidad verrrrrr ',
#  'no llueve todo finde    va llover  justo  nueno  acuerdensen ',
#  'datos actuales  santafe barrio sgto  cabral                          lluvia hoy     ',
#  ' lluvia   ',
#  'que pasa salen lluvia     yo no puedo ni salir cama  ',
#  'ayer  rayos salen tierra   nadie dijo  ',
#  'a novio haces feliz tan poco    hoy hice tuco  muy rico  muy modesta pero verdad  dijo    veces estaba  gracias hacer comida tan rica  lluvia  amo ',
#  ' reprogramacion  taburetes  arte       lluvias  subasta taburetes  reprogramada  lunes          ',
#  'se   pecho trueno xd ',
#  'me estoy dando cuenta lluvia va fallar asi voy poner estudiar  ',
#  'me iba quejar  volver caminando lluvia pero    bobos   cuadras tormenta   calles inundadas viento frio  ',
#  'los voy poner contexto  hermano   am  lluvia   sujeto  individuo  cuando sale toma cantidades muy bajas alcohol  pero siempre puede haber   noche fue    ',
#  'ola bb  invitado casa no hacer nada  solamente acostarnos  darnos muchos besos escuchar llueve enviar ',
#  'no inverno   cocino comio chocolate entero   resultado   dos dias lluvia granizo  ',
#  'otro inconveniente intensa lluvia  basura problema todos    interes general ',
#  ' boluda fue todo muy chistoso porque dije  oyes  escuchas  boludeando justo  ',
#  ' esto verdadera   intendente    hace   no pasa nada    hace plata mis impuestos    laguna forma cada vez llueve calle silva entre reconquista e iberlucea  haga algo favor     ',
#  'mks  plus faltaba  fecha abuso  quede trueno  ',
#  'como odio clima asi cosa pone muy mal humor  porque no llueve durante semana concha madre ',
#  'hace dos semanas paso mal secando ropa  lluvia remil orto ',
#  'malabia santa    sanjusto  calles llenas agua luego tormenta   ',
#  'desde         probabilidad lluvia  todo  lluvia   afuera sol raja tierra  metereologico chupame huevo    ',
#  'maamaa mira llueve quiero dormir ',
#  '  veritas  estaba preocupada lluvia    lpm ',
#  'tremendo rayo cap   alarma auto  ',
#  'que paja dormir sola estos truenos orto ',
#  'lluvia amo ',
#  'que abuso llueve ',
#  'dormir cuchareando mientras llueve deberia ser maravillas mundo  ',
#  ' rayos ',
#  'hoy si no llueve pinte mas loca casa sola pa  ',
#  ' lluvia agua  estrellas  ',
#  'juega si llueve fin  active joda casa ',
#  'ay no  juro estoy cagada hasta patas miedo tengo tormenta  \\U0001f62d ',
#  'team rebellion racing  dialogo radio   lotterer termina preguntando tecnicos pit  apuntando    ademas insiste  no facil conducir bajo estas condiciones  lluvia entender cockpit quieren decirme  \\ \\ lotterer expiloto audi supercar hibr   ',
#  'culia primera vez iba salir  llueve ',
#  'se viene tormenta  sin luz  calor insoportable  mosquitos docenas  quiero morir  ',
#  ' ',
#  'lluvia querida  ',
#  '       vez   cuando era chica   centella cocina     canilla cocina  fue resplandor impresionante  rayo habia caido  jardin ',
#  'aunque yo oculte tras  encuentre campo lleno   no  manera rayo luna  vayas ',
#  'que linda lluvia solo falta    ',
#  ' no puedo dormir solo lluvia  ',
#  'lluvia    ohh seee   mis  tienen orgasmo  ',
#  'avisame si falla rayo ',
#  'que lindo dormir chongo lluvia fondo  lastima falta chongo ',
#  ' lluvia pleno  buen  ',
#  ' anoche amagaron  hasta     pero suerte tenemos   pero llueve mucho    ',
#  'llueve      ',
#  ' anunciado lluvia toda semana llega llover  muero   ',
#  'truenos  ',
#  'lluvia metele  ',
#  'si llueve va ser siesta perfecta  ',
#  'se presta lluvia pa dormir  ',
#  'cosa hermosa tormentas  ',
#  'seguro llueve ',
#  'dicen pobre uruguay  tormenta     pero           ',
#  'que lindo dormir lluvia  ',
#  'que linda lluvia  ',
#  'ya no gustan mas dias nublados lluvia nanana mansa depre loco ',
#  'q lindo dormir lluvia  ',
#  'lluvia jugar      ',
#  'me anote   alpedo siempre llueve cuando voy  petiton triunfando ',
#  'lo  organizaron mis amigas venir desayunar centro  ni tormenta   tormenta culpa ellas    ',
#  'cocinamos ulises llueve  ',
#  'buen  lluvia  ',
#  '   no solo  colgar  ',
#  'y lluvia pa cuando  ',
#  'antes odiaba dias lluvia  ahora amo todo ser  lindo martes    ',
#  'el    lluvia  pero suerte tengo seguro sale alto sol ',
#  'linda lluvia dormir abrazados yo sin ',
#  ' facha tornado lpm ',
#  'q lindo llueve ',
#  'toda semana sol raja tierra pero llega sabado hay todo llueve concha hermana ',
#  'yendo consulta lluvia  aprobarme solo no quedarme durmiendo ',
#  '   chino  mudo     ir volver caminando casa kempes ir ver belgrano contra rafaela lunes bajo lluvia        vs velez torneo        ',
#  '  cruce alguien tenga tantas ganas  yo  no mienta ni mienta  baile entre tormentas   ',
#  ' lluvia   ',
#  'buscando ganas volver  lluvia ',
#  'lluvia   lluvia   lluvia  ',
#  'traigan paragua algo lluvia  ',
#  'estoy acostada escuchando lluvia  parece perfecto ',
#  'en otros paises  canales noticias tienen tambien   camaras contando desarrolla tormenta  durante    minutos  ',
#  'la otra vez vine buenos aires  cagarse noche   domingo cancha cagado calor  ahora lluvia todo hoy posiblemente    nunca  normal no   ',
#  'con lluvia  estar   ',
#  'se copo lluvia ',
#  'hice esperar  abajo rayo sol poder terminar descargar playlist pepo porque  prioridades ',
#  'ay lluvia  ',
#  'lluvia sol rosario  ',
#  'alguien dice cuando va llover    lluvia ya cansas ',
#  'ahora  tiempo  rosario barrio centro        hum              pres          viento    wnw lluvia hoy     ',
#  'ahora  tiempo  rosario barrio centro        hum              pres          viento   ese lluvia hoy     ',
#  'amo  lluvia   ',
#  ' nono    vino grito  leo  mujer dijo avise hora antes llegue tormenta  ya  casilda  juntamos todo  nos fuimos    llegar  llover  mejor vecino  ',
#  ' lluvia ',
#  ' susto pegue  ',
#  ' rayos  prestas diccionario  ',
#  ' ser despreciable  todos  lluvia pasa mismo ',
#  'me desperte alta tormenta nananana  ',
#  'donde lluvia  iba haber hoy     niego jugar calor  ',
#  'el clima rosario  mesa adentro     anuncian lluvias hasta   enero    ',
#  ' perezlindo  encargada   biblioteca popular    lunes   llegar     ',
#  'yo veo ami perros asusatados tormenta   baja tristeza perros mascotas estan  ',
#  'lo odio  lluvia inundaciones mamita querida horrible ',
#  'datos actuales  santafe barrio  norte                          lluvia hoy      ',
#  ' lluvia viene vs desis ',
#  '          mate   tere  ahora todos mismo idiotas primer lluvia  primer   primer   no puedo ver  esa idiotez    ',
#  'hola  tabossi entre  no llueve pero refocila   anoche tronaba pero no  nada hoy tuvimos sol pleno mucho calor  zona centro entre  echo desastre mucha piedra ',
#  'buscando alguien ver lluvia estrellas ahre ',
#  ' violencia sin fin  mataron tres personas  horas  lluvia balas parece no acabar   fatales hombre     dos          todos murieron episodios distintos    ',
#  ' capture momento justo rayo  sin luz barrio san         rayo  tormenta  cordobaargentina  thunderbolt  epec    ',
#  'nunca vida habia visto tantos rayos asi gigantes  ',
#  'estoy mil podrido mojarme lluvia  parece joda ',
#  '  dios si lluvia bendita pal tiene techo  disgracia castigo cielo  pal desamparau  j l   ',
#  'que feliz domingo lluvia guiso  ',
#  'pero soledad lluvia ',
#  'que cosa hermosa lluvia  hermosa tormentas   dios no puedo ser  fan    porque no tiempo m  mimo alma dormir sonido tormenta fondo  ',
#  ' granizo localidad maria juana    sabado tarde    ',
#  'si no llueve tengo salir  no queda otra ',
#  'amo lluvia ',
#  '  lindo mundo lluvia  no   ',
#  'con lluvia todo nosotros viajamos igual  ',
#  '  climarafaela          hum        bar         lluvia       viento       ',
#  'fui gimnasio estoy yendo voley  si viene tormenta  ya saben  ',
#  'y lluvia  ',
#  'lluvia ya odio ',
#  'qien puede asegurar qe    no llueve  porqe donde meto entrada caliope   dej aa ',
#  'y sera unico arrecha lluvia   o ',
#  'te amo lluvia ',
#  ' cordi lluvia ',
#  'tremenda lluvia  viento   culiaw  nada voy che ',
#  'ah  pero infinity war  lluvia spoilers   ',
#  '  ojo tambien tormentas    ',
#  'con cantidad lluvia pronosticado  diez   atreven organizar pool partys  ',
#  'con lluvia estaria necesitando ahora conmigo acostados abrazados decirte cuanto    ',
#  'esta lluvia presta estar ',
#  'como amo  ',
#  'necesito helado lluvia ',
#  '  agvnet          hum        bar          lluvia    viento      ne  ',
#  ' tobillera      descargas rayos si hay alguna tormenta    ',
#  ' aparentemente  vender europa  no  mal  pero     estadios  estar mejores condiciones  aunque si llueve mucho poco tiempo  no hay  aguante   pueda jugar  sino vuelven infumables todos  ',
#  'la lluvia mate llevan muy bien   buenlunes  descubritulugar  ',
#  ' ser ilegal ir cursar lluvia ',
#  'muy linda lluvia    hermosa gusto  pero chance hay frene toque hasta vuelva trabajar   ',
#  ' climarafaela          hum        bar          lluvia    viento     e  ',
#  'la concha yuta  pq mierda anda tan mal cablevision cuando hay tormenta ',
#  ' llueve yo no puedo dormir ',
#  'semejante tormenta no refresque carajo  ',
#  'la tormenta era  linda estando casa  ',
#  'no soporto llueva odio lluvia parece bajoneara mas ',
#  ' lluvia ruedas ',
#  ' villamaria       hs        min              max                hum      viento     ne  pres       lluvia     ',
#  'me estoy llendo trabajar larga lluvia todo  hermosa suerte mia  ',
#  'datos actuales  santafe barrio  norte                          lluvia hoy     ',
#  '  lluvia sabes  va estar     tenemos salir si si ',
#  'escucha llueve amigo  nas ganasss morsear   culiaa ',
#  'lo mas lindo   irme dormir sonido lluvia ',
#  'no puede largar llover ahora puta madree  tengo cruzar pueblo bici llueve  ',
#  'dia lluvia laburamos asi     ',
#  'esta lluvia  favor  necesito estar todo  cama ',
#  'estoy sentada tranqui  viendo rayos pajaritos cantando fondo parece perfecto ',
#  'ya intentamos todo durante  largo  tormentas soledad dolor ',
#  'el dilema ir gym lluvia   mondaymood ',
#  ' villamaria       hs        min              max                hum      viento     e  pres       lluvia     ',
#  '       comienza cielo   varios lluvia  temperatura actual        ponete  variedad calidad noticias auspiciadas  supermercadoslareina  ',
#  'lluvia hija mil puta ',
#  're piola lluvia   ',
#  'que lluvia no corte noche ',
#  'que lluvia no detenga    hermoso entrenamiento   felicitaciones guapos   seguimos                llueva truene   ',
#  '  parecia era az l  cuando salimos llorar pedo tormenta cana   ',
#  '   eso  creo problema empieza ahora   napa  partir ahora cualquier lluvia moderada complica  ',
#  'la lluvia  birra mis amigos  ',
#  ' manda volverme plena lluvia ',
#  'que linda lluvia  tanto calor ',
#  'si dormir escuchando lluvia hermoso imaginate  ',
#  'no  ni lluvia  ',
#  ' agvnet          hum        bar          lluvia    viento     n  ',
#  '                      gracias querida lili     lluvia bendiciones       ',
#  'mmmmm llueve   ta lindo estar eeeel ',
#  'todoos mis hermanas van salir  ver si medio noche parte rayo  gracias  ',
#  'ya espantaron lluvia estupideces manga mogolicos ',
#  'amo llueve  ',
#  ' villamaria       hs        min              max                hum      viento      nne  pres       lluvia     ',
#  'un dia lindo pero otro llueve despues vuelve estar lindo pero ahora vuelve llover ',
#  'lluvia estudio no van mano ',
#  'que linda noche lluvia dormir   pongo    realidad no tengo    pero queda piola decirlo ',
#  'hoy estaba ideal tomar sol  siesta  acabo ver clima dan lluvia hasta semana viene  ',
#  'faaaa mirame siempre  esos ojitos hermosos tenesssss  moje no fue lluvia  nnniaaaa ',
#  'puchito   lluvia atr ',
#  'que lindo dormir lluvia  ',
#  'existe algo mejor lluvia  respuesta no ',
#  'hizo cuadro lluvia ',
#  ' tormentividades  rosario   otra jornada sin  colectividades     lluvia      ',
#  ' venir no dormir lluvia  enviar ',
#  'esta lluvia ciega cristales  perdidos arrabales negras uvas parra cierto patio ya no existe  mojada tarde trae voz  voz deseada  padre vuelve no muerto     borges   ',
#  'llueve puta madre pero tomo campari igual ',
#  'se esperan lluvias tormentas desde  hasta  inclusive zona central oeste   sol   mejoramientos pero todos  periodo  desmejorar   hasta              ',
#  'zarpada lluvia anoche    ',
#  'llueve tengo fiebre no estoy cama  estoy sufriendo ',
#  'mabeel tormenta vienee  ya veo sin dormir noche  ',
#  'truenos  ',
#  'chiquito rayo  gt   lt  ',
#  'con lluvia  igual  resultado  mismo siempre domicilio encima   ',
#  '  centro cultural parque     veinticinco  desde chispa fundacional   vivo   visuales       domingo         entrada        caso lluvia  reprograma lunes     ',
#  'en serio hay personas    nunca pase  no das idea mal  pasando todas esas personas  raro tanta lluvia no llegado agua tanque  ',
#  'lluvia  chiquero      sea  donde sea     papa   ',
#  ' queria empezar correr  lluvia mierda ',
#  'un dia soleado hace calor insoportable otro hace frio llueve  loco  ',
#  '  siempre llovia mis francos  ahora ya no trabajo llueve cuando tengo salir vida odia ',
#  'si viene tormenta algo  fuerte  yo puse estudiar ',
#  'la lluvia  ',
#  ' aguanta mala  si llueve mojan todos no  xd ',
#  ' solicitaron  urgente  plaza  alrededores  dado   puente  ellos  hecho e  agua viviendas ubicadas sobre canal maestro sur  tras  lluvias   ',
#  'ya  lluvia eh   ',
#  '  agvnet          hum        bar          lluvia    viento      so  ',
#  'lave moto  millones mensajes mis  diciendome  lluvia   pero si  seguramente llueve  esa suerte  ',
#  '  tus musas    yo estoy  pero lluvia no deja concentrar     ',
#  'que lindo dormir lluvia  falta   ',
#  ' hermoso haberme dormido escuchando lluvia  despierto sigue lluvia    duda no voy salir casa   ',
#  ' climacordoba temperatura        tormentas            humedad         viento     suroeste   datos hora            clima    tiempo ',
#  'nada  feo ir caminando centro tormenta auto  completo agua  ',
#  ' yo doy abrazo oso  noche  si no llueve  ',
#  'mejor no pongo  lindas noches lluvia  ',
#  'y lluvia  candela   ',
#  'como explico mucho dan miedo tormentas estoy durmiendo sola porque mama no quiere venir conmigo ',
#  'dios  lluvia hora dormir unas sietes maravillas mundo  ',
#  'che todo bien lluvia pero yo tengo hacer cosas ',
#  'adivina si  auto ayer ahora llueve puta madre ',
#  'fin semana abundantes lluvias  recomiendan limpiar canaletas  rosario  ',
#  'un miedo tormenta ',
#  'de rayos gamma rayos  nuevo  permite descubrir   previamente desconocida   ',
#  'mientras no llega lluvia  espera  caluroso ciudad  ',
#  'hasta cuando lluvia hermano  ',
#  'a aman verano     noviembre hacen    grados lluvia  aguante  caretas ',
#  'mates  estudio lluvia  ',
#  'no queje  luz porque noche nos  show rayos oscuras  digno ver estamos sentados reposera afuera casa   ',
#  'esa lluvia  ',
#  'tormenta no  esperar hasta vuelva    ',
#  'que lindo llueve  no pare  ahora  ',
#  'como llueve lcdsm no anda naaadaaaaaa ',
#  'lluvia mierda dejo sin luz mojo toda cama ',
#  'flashie  parado lluvia fo ',
#  '  cielo parcial cubierto cubierto mejoramientos temporales  condiciones inestables algo inestables  alguna posibilidad lluvias  dispersas durante jornada no   eventos  intenso   ',
#  '  agvnet          hum        bar         lluvia    viento       ',
#  'que lindo jugar lluvia  ',
#  'llueve  feliz  hacen   solo decir parecer   ',
#  ' climarafaela          hum        bar         lluvia    viento     nne  ',
#  'despertarme hora lluvia fondo  cagada hambre no tiene   ',
#  'gracias twitter argentina hacerme enterar llueve       ',
#  '  climarafaela          hum        bar          lluvia    viento      sso  ',
#  'si dios no existe     explicas lluvia     jaque mate ateos  ',
#  'truenos bombas   puta madre quiero dormir ',
#  'yo queriendo ver lluvia estrellas queriendo verla ella ',
#  'lo  diferenciaba directv  ver bien  lluvia viento ahora ni eso  asco  ',
#  'ya puede largar lluvia ',
#  ' agarre cabeza rayo  dijo motta  quede diciendo dieciuno   ',
#  'un mes vacunando  casa casa hasta lluvia  hablame amor profesion ',
#  'hermosa lluvia dormir eia  solamente eia  ',
#  'se espera semana inestable tormentas     ',
#  ' lluvias  impulso soja   informe exclusivo clima auspiciado   ',
#  ' entero  vino tormenta  yo  dormida trabar puerta pieza  segui durmiendo campeona  ni   ',
#  'hace   horas estoy esperando pare lluvia salir correr     ',
#  ' cosa hermosa  ',
#  'la lluvia afecto cerebro ',
#  'aca cn uma arriba  porque tiene miedo tormentas ',
#  '  escrito biblia si no llueve  baile  llueve uno dos antes ',
#  ' inundado autos quedados flore ',
#  'llueve pinta enredar piernas  no digas  no digas  no digas  no digas  no  dejemos ser tan artistas hables  quiero verte ',
#  'con lluvia trabaja igual ',
#  'lloraste tanto riber pley tus  transformaron lluvia concha madre ',
#  'esta tormenta viene  fuerte eiaa  noche  va volar rancho  ',
#  ' mucha tormenta salir caminar querida ',
#  ' informa    sin fin excusas evadiendo cualquier tipo responsabilidad desidia expone cada vez llueve trabajadorxs usuarixs  trabajamos peligro electricidad llega    v corriente continua caso linea b ',
#  'se corto luz vino lluvia viento lpm    ',
#  'en momento cuando  luz velas porque tormenta corto luz barrio  tenes     das cuenta necesario cargador  ',
#  'no llueve yo empiezo matar gente voy tener sentar tomar olvidarme dolor pierna  ',
#  'esta lluvia  vengadores novio  mejor plan mundo  ',
#  'todavia sigo esperando lluvia estrellas  ',
#  'soy fan rayos ',
#  'es domingo duermo novio   lluvia lunes jueves  ',
#  'luka manda videos tormenta desde ventana cuarto  placentero pueda existir ',
#  'lo peor calor estoy parada rayo sol derretida maquillaje ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'ahora  tiempo  rosario barrio centro        hum              pres          viento    w lluvia hoy     ',
#  ' si pinta    cuando llueve sol  ',
#  'y bueno  salir rato no ver si llueve ',
#  'que si estoy escuchando suenan alarmas llorando mientras llueve              si  ',
#  '  todos  comenzamos  temperatura      ciudad san luis   pronosticada     tarde anuncian tormentas  compartimos nuestros  arrancar  bien informados   ',
#  '   viajando colectivo   llueve ',
#  'ya tormenta ya  concha madre  ',
#  'hola  no gustan tormentas   venir dormir conmigo   hago pururus muy ricos  pensalo  enviar ',
#  'lluvia  chapas skeeeere ',
#  'quiero estar yendo  lado morir camino  choque cole  caiga rayo  alguien mate  sea pero ya entienden ustedes voy ',
#  'gracias tanto lluvia ',
#  'la tormenta interminable  hacer refresque poco  no  ',
#  'yo  anoche esperando lluvia estrellas  lloviendo ni bosta  ',
#  'de donde salio lluvia igual mejor llueva toda noche ',
#  'que  orto   rescato lluvia cumple mari  nada mas ',
#  'que ganas joder lluvia  ',
#  'con tormenta pretenden estudie final  puta madre pario  ',
#  'wacho no puedo estar tan enamorada trueno waso hermoso ',
#  'me aprecie chomaso llueva porque algunos  cuando llueve no van colegio  porque no pueden yo  chomaso no vayan estos   ',
#  'peeero hermosa lluvia  ',
#  'lluvia besos gar      ',
#  ' villamaria       hs        min              max                hum      viento     ne  pres       lluvia     ',
#  ' primavera resiste  tras dos  sol  vuelven lluvia       rosario   ',
#  ' vida no esperar pase tormenta  aprender bailar bajo lluvia    argentina  ',
#  'las lluvias tormentas momento vuelven  zona central litoral  ',
#  'mi perra tiene miedo truenos amo ',
#  'objetivo  dormir tranqui aprovechar llueve  especial  dificultad  ida final pensar si juega hoy   ',
#  'a clase persona relaja tipo tormentas parece van volar casa  escuchas piedras techo  ponen nervioso    leo twitter ponen esas cosas no entiendo  ',
#  'me encanta olorcito lluvia  ',
#  'yo creo truenos estan mas no ',
#  'los dias lluvia  ',
#  'necesito novio  lluvias ',
#  'truenos chotooss ',
#  'me pueden explicar pinchila hace    grados hay sol toda semana justo finde llueve clima ogt ',
#  '  total  ellos tienen custodia  pueblo parta rayo nos acribillen celular  no importamos    ',
#  'hoy fue primer dia serio vacaciones  todo debo lluvia  ',
#  'que  culiau dan alto cagazo esos truenos ',
#  'que hermosa lluvia  ',
#  'justo semana necesito sol   bye lluvia ',
#  'como olvidar noche silvia  luz nos  medio toda tormenta  igual nos fuimos estuvimos joda hasta  am  toma pa vo ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  '  climarafaela          hum        bar          lluvia      viento      ',
#  'necesitaba correr bajo lluvia herrrmosura  ',
#  '  horas caminando rayo sol no terminarme comprando nada ',
#  '  climarafaela          hum        bar          lluvia      viento      ',
#  'cosine vino tormenta  ',
#  'esta lluvia hace tener mas   dormirrrr ',
#  'fuaaaaa nose si llueve ',
#  'noche lluvia pide gritos  grey anatomy ',
#  'noooo   esos truenos  ',
#  'ay  ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'esta lluvia mierda no quieren parar   sinas  sinas no paran llorar  ',
#  ' hace cuando hay tormenta     ',
#  'esta lluvia hermosa quedarse mirando tele todo dia ',
#  'hoy voy tomar hasta rehenes si llueve agua lluvia  ',
#  'mucho trueno mucho trueno no va caer ni sola gota acordate digo ',
#  '  mudarse   mudarse lluvia  ',
#  ' airedenoticias      max    algo nublado  e inestable probables precipitaciones tormentas dispersas  neblinas bancos niebla  viento leve moderado sector norte cambiando sur  poco cambio temperatura   ',
#  'buen dia    mirando pajaritos lluvia   martes  ',
#  'por dios esos truenos ojala pegue uno ',
#  'como no puede gustar lluvia  mas hermoso tranquilo ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'quiero prestarte    importas mucho dejarte mucho tiempo   sali pagar unas cosas volvi lluvia   pongo pensar todo esto nos pasa no quiero pase mas dia   podamos sentir todo tenemos nuestro interior ',
#  'esta lluvia si c mamo ',
#  'ahora  lluvia doce noche pleno brindis   fiestas todossss  ',
#  'llueve todo  menos   lpm   gitana ',
#  ' santafe   quintas estaban sembradas pleno   lluvias  cayeron      complicaron poco quinteros perdieron casi          ',
#  ' lastima gente tiene ir trabajar si si tormenta   yo  no voy cursar ni pedo ',
#  '    ahora cielo despejado  ya fue vientito fresco     si junta humedad  llueve otra vez    ',
#  'porque siempre llueve cuando tengo quedarme toda noche despierta estudiando  ',
#  'lluvia culiadasa no puedo volver laburo ',
#  'escucha llueve yo tengo ir colegio  ',
#  ' buenos  llueve viso pero ahora  viento  levantado eso   ',
#  'como gustaria lluvia cresca mantenga agua rio sierra   ',
#  ' callate bofe habla lluvia ',
#  ' federala debido lluvia  madrugada hubo cambio planes  racingcba  plantel mostaza merlo     horas predio   ',
#  'que lindo escuchar lluvia  ',
#  'lluvia reputisima madre mil pario ',
#  'que lindo fue levantarse  sentir olor humedo ruido  escuela quien junaaa   ',
#  'lo  quiero  agua caliente  estar    min esperando bondi abajo lluvia laputamadreeeeee ',
#  ' santafe    lluvias durante todo lunes   ',
#  'primera vez coincidimos  chicos   tanta lluvia        ',
#  'aiiiii truenos lluvia  ',
#  'a sobrina  noel trajo rayo mcqueen cars    usa bombacha  lleva  hace parado  pone protector solar come chocolates ella ',
#  ' granizo  barrio villa cabrera   cba capital ',
#  'que tormenta presiento ',
#  'la puta madre no fui rendir  maldita lluvia traicionera ',
#  '  climarafaela          hum        bar       lluvia    viento      ',
#  'gente  llueve desde nacimos  ya cansa fotito tormenta todas semanas ',
#  'me gusta verano cuando llueve  muy fresquito  sea no gusta verano  ',
#  ' claro    cuando vimos tormenta  tuvimos apagarlo  horno    siesta   dios    terrible   ',
#  'hola queres venir mirar serie dormir lluvia  enviar ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'que tormenta saque todo malo  alivie  ',
#  'pronostico domingo       calido humedo  nubosidad aumento  baja probabilidad tormentas aisladas tarde  viento leve sector norte rotando sur  leve ascenso  max    c  ',
#  'por lluvia   techo escuela ipv      ',
#  'toda  familia  hay tipo tornado huinca  yo  sentada mitad patio comiendo alto asado complejo  salud  ',
#  'ya entendimos nos va partir rayo  si no nos parten ustedes basta ',
#  're salir correr lluvia ',
#  'que hermosos truenos escucho aunque odio  pero largue yaaa ',
#  'uno queriendo ver famosa lluvia estrellas cielo  mas nublado abuela bruno ',
#  'emilia dice decearia dormir abajo lluvia amo  ',
#  'mi  rescato medio lluvia piedras perrita  estaba  asustada papa todo bueno mundo ',
#  'es      no supere miedo truenos ',
#  'alarma lluvia          vs dsis  ',
#  'e loco onda tormenta barrio cayeron   gotas locas otros lados dicen  dilubios ',
#  ' castillos  duendes  toman cerveza  llueve todo     ',
#  'jornada  suspendida lluvia   ',
#  ' lluvia  dicen  mientras no sea  patitas todo bienvenido  ',
#  ' caiga rayo     ',
#  'tormenta  santa fe capital desde octavo piso hotel  ',
#  'se viene lluvia mierda  ',
#  'calles anegadas cortes luz tormenta    ',
#  'lpm   amo lluvia pero porque domingo noche  alta paja levantarse ir escuela otro  ',
#  'ni llueve encima  ',
#  ' amo  lluvia ',
#  'hermosa lluvia dormir abrazando almohada ',
#  'la lluvia no buena   ',
#  'yo empapada lluvia  ',
#  'lluvia mierda  moje todo cuando estaba caminando ahora  saliendo sol ',
#  ' holapavonarriba  pronostico lunes     nuboso lluvias tormentas  algunas localmente pueden superar      viento          cambiando norte hacia noche  temperatura           c humedad       bajando       ',
#  'me voy quemar divertido pa esperar lluvia entonces  ',
#  'hola  queres venir dormir siesta conmigo ruido lluvia fondo  enviar ',
#  ' tormenta  ',
#  'si hoy llueve voy lotus ya fueeee ',
#  'que onda minas estan todo tiempo tuiteando  chongo dormir   chongo tomar   novio salir hacer after  culia sali buscarte uno twitter no vas conseguir deja romper huevos ',
#  'no  olvidado alguien subir foto granizo   ',
#  ' ganas lluvia aire fresco  cielo cubierto posibilidad vuelva llover  menos    amanece pero nota   mucho  abajo durante     ',
#  'con lluvia igual sade  ',
#  'creo hoy  uno  bajo lluvia   incluyo  ',
#  'me meti pileta estoy tomando sol   llueve ',
#  'de regalo cumple pedi barba tormenta  ',
#  'que hermosura sonido lluvia dormir  ',
#  'se viene tormenta pero salgo igual    ',
#  'a verga viene tremenda tormenta ',
#  'buen dia gamers dia especial viciar pero cuiden pcs lluvia fuente mas barata certificada       macri hijo puu    ',
#  'algo mejor dormir escuchando lluvia aire     ',
#  'salir crocs lluvia male sal ',
#  'venirme trabajar lluvia ver novio sigue durmiendo  dio bronca ',
#  'para no preocupen estoy hablando lluvia cumple no tengo crisis  pero igual siempre estoy cerca ',
#  'lluvia  netflix  no pensalo    ',
#  'por favor cago miedo cuando llueve hay viento vez literalmente caniche ',
#  'una tormenta vaso agua  ',
#  'lluvia zamba  linda    ',
#  '   millll rayos segundo caen menos  creo kede corto    ',
#  ' ahora   graniza capital provincial  mandanos  desde donde    ',
#  ' ver lluvia meteoritos conmigo      ',
#  'alguien explica momento vino terrible tormenta  ',
#  'domingo lluvia pa mirar netflix  ah no  no tengo internet ',
#  'si no parte rayo parto medio yo ',
#  'se viene lluvia  ',
#  'al fin paro lluvia    ',
#  'la lluvia  final turismo carretera             carburando       ',
#  'oriente medio llena   intensas lluvias  ',
#  'y si eso pasa voy salir afuera unicamente sacarme ganas dar vueltas tornado  ',
#  '  creo ron ron balu  dijeron no  lluvia  todos sabemos paso   ',
#  'que linda lluvia xd ',
#  ' ver si estaba lluvia estrellas estaba nublado  puede fallar ',
#  'ahora madrugada        lluvia estrellas si no desnubla voy tener empezar matar rehenes ',
#  'me tome tarde hoy aprovechando lluvia  hice pizzas caseras  milanesas  quipe   pan ensalada frutas   amor tengo  ',
#  'esta lloviendo fin puta madre amo lluvia amo olor tierra mojada ',
#  'lluvia  vida  ',
#  'linda lluvia ',
#  'acabo leer partir     centennial  rayos voy tener cambiar   ',
#  'llegue gym ya estoy arrepintiendo  no quede dormir hermosa tormenta  ',
#  'ni loca viaje moto lluvia     ',
#  'le dije   saco foto rayo das     pesos haces tortas   estoy     pesos    ',
#  'como hago levantarme cama e ir escuela lluvia yahoo respuestas ',
#  'que onda tormenta ',
#  'me fui particular  lluvia   empapada     barro culpa gomones    casa no hay nadie dejaron fuera    jueves  ',
#  'me falta  ver tormenta   ',
#  'pinta ver peli esperar venga tormenta  ',
#  'datos actuales  santafe barrio  norte                          lluvia hoy     ',
#  'no tener miedo trueno rayo algo  pero hoy ahora pieza fumando tengo  miedo nunca  sopla viento yo ya flashie   veces dieron   paros  acb ',
#  ' capital tormentas momento actividad     ',
#  '   lm hay promedio   asesinato cada     responsable eso generar pobreza sostenerla  cada vez llueve  gente inunda  hacer vivir vecinos marginalidad  dignidad  puedo seguir  lamentablemente  lista larga  ',
#  'la parte fea llegar casa acostarme sola tormenta ',
#  ' villamaria       hs        min              max                hum      viento     n  pres       lluvia     ',
#  'sos lluvia pink floyd  ',
#  'que lluvia mierda ',
#  '   sino llueve lpm  ',
#  'lo mejor hoy era pesca otra vez lluvia cago ',
#  'que lindooo voy dormir escuchando lluvia   ',
#  'se viene lluvia parece haha ',
#  'ayer humedad lluvia mierda tuve ir hacer tramites infierno  sea capital  pelo    ',
#  '  climarafaela          hum        bar         lluvia      viento     ne  ',
#  'no entiendo rayos gente  hablando  felipa  ',
#  'dia tormenta ideal venir visitar tus viejos  justo noche    ',
#  ' verga vuelvo casa lluvia culia ',
#  'yo no ustedes pero realmente preocupa durante meses no  ni gota  sequia casi todo  ahora ya van   semanas llueve todo  tormenta  viento fuerte  estamos destruyendo literalmente planeta  ',
#  ' llueve mucho dormir mucha tormenta ',
#  'acabo sentir trueno terremoto  raro vida     hasta ocote  ',
#  'el abuelo  hasta  cuando nieto  lluvia  ',
#  'ahora       arrecifesmegusta  lluvias  crecida arrecifes  argentina  ',
#  'ahora lluvia  naturaleza ama ',
#  'q hermosa lluvia pa dormir    ',
#  ' llegaba  tormenta  rosario       ',
#  'soy torpe caminando   lluvia paraguas ',
#  'grax lluvia ',
#  'la lluvia nos pego oleee ',
#  'ya  olvidado era rayo sonido ',
#  'quiero vuelva lluvia  pero no   favor ',
#  'lluvia amo  truenos odio   ',
#  'soy tan fan tormentas   ',
#  'otra historia abuela bruja  hoy llame corte tormenta potrero dijo estaba justo  remis   minutos manda mensaje juro fue tormenta   ',
#  '  si amiga voy  moto verga cuando llueve ',
#  'llueve hace triple calor ',
#  'acostarnos escuchar llueve eso necesito ',
#  'son       llueve bien  no tengo  faltas mal  ',
#  'mi  va matar cuando llegue vea hace rato puse lavar toallas llueve  ',
#  'datos actuales  santafe barrio candioti norte                          lluvia hoy     ',
#  'me voy quedar despierto solo ver lluvia estrellas ',
#  ' carlos vota   tiene superpoderes   rio  rayo   ',
#  ' villamaria       hs        min              max                hum      viento      n  pres       lluvia     ',
#  'recordatorio  lluvia  no cruzar calle saltando  ',
#  'si viene arriba solo rayo temo    ',
#  'que linda lluvia siga hasta      ',
#  'que mierda hago ahora llueve  ',
#  'qur bella lluvia ',
#  'se multiplican      ganas quemar dias lluvia ',
#  ' rosarioar lunes              probables neblinas  cielo parcialmente nublado nublado  probabilidad tormentas aisladas  vientos leves noreste   tarde noche  cielo nublado parcialmente nublado  vientos leves sector  ',
#  'las lluvias dejaron algunos anegamientos   granizo  lluvias dejaron algunos anegamientos   granizo ',
#  '  lluvia sobre  rosario   light rain  temperatura actual    c  ',
#  'mi   anoche   am medio tormenta            trabajar muchas horas  rato vuelve ir nuevo porque tormenta dejo muchos hogares sin techo     etc  realmente merece mejor ',
#  '  bueno  llueve cada ratito  ',
#  'siempre inauguran colectividades llueve  pero fija siempre pasa   ',
#  'gente  ya todos estamos viendo tormenta  no necesario fotitos  ',
#  'padre sale abajo lluvia sacarle fotos mama cuando pase viaducto corriendo maraton  yo ex tenia pedir    veces  parada no violen roben etc  nunca acepten menos primer ejemplo  n u n c  ',
#  'quiero ir colegio  pero seguro llueve   faltar  chau posta puede cama   ma no dejes faltar ',
#  'hermosa lluvia  ',
#  'estoy empezando   puede paetir rayo xfa ',
#  ' hola  somos equipo relampago   estamos recolectando  sobre eventos severos ocurridos argentina parte proyecto  relampago     tienen  autores video  ',
#  'aguanta   min tormenta ',
#  'no van negar   lindo cuando llueve ',
#  'despertarme  rayos sol  ',
#  ' obvio   suerte sola vez   di hermano dice  che  onda apunte   lluvia  si supiera     ',
#  ' estos   visto  periodista medios militando         ahora   clacso ',
#  ' calma antes tormenta    ',
#  'llueve sale sol   ni loco tiempo ',
#  'por parta rayo  ',
#  'esta lluvia novio  ',
#  'ligue    saint ettiene    robert      wahbi khazri      kolodziejczak      nantes    liga  rayo vallecano     embarba      eibar     cardiff city    aron gunnarsson     junior hoilett      wolverhampton    matt doherty      ',
#  'si hay algo mas lindo domingo cba lluvia no quiero saberlo  ',
#  'bueno ya  lluvia truenos no puedo escuchar  ',
#  'pues ya asoma frente lluvias  nieves viento    ',
#  'me tiene podrido lluvia men  ',
#  ' ya veo otro    nos  corriendo rayos ahre ',
#  ' ponemos onda lluvia  estamos pensando todo darte mejor    viene  celebraciones amor  ponemos todo     ',
#  '    peleada rayos  iba pasar ',
#  ' pues poder puede   lluvia no nos amargue   ',
#  ' vengo desde cba talar   llueve dos manos  ',
#  'datos actuales  santafe barrio sgto  cabral                          lluvia hoy     ',
#  'dia lluvia  paragua ',
#  'datos      hs          hr      presion        vto     nublado   visibilidad   reducida lluvia debil ',
#  '  mira   nos juntamos hago tortas fritas  tenes ganas  ',
#  'puto  puta lluvia puto todo  ',
#  'llueve      ',
#  'el pueblo entero pide pare lluvia  ',
#  ' tomar lluvia  decimos hacer algo sale mal ',
#  ' agvnet          hum        bar          lluvia    viento      ne  ',
#  'ya cansando lluvia     ',
#  'que lindo inunde toda casa cada vez llueve   hoy espera  cortito  dije nunca vida  ',
#  ' agvnet          hum        bar         lluvia    viento     n  ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  ' va gorrita eso frena impacto rayos uv ',
#  '  rosario fiesta  colectividades ratifica masiva convocatoria  hoy desarrolla  jornada   desfiles   rampello       ',
#  'bien piola lluvia ',
#  'noche tormenta cba  ilegal dormir sola noche asi    ',
#  'se viene tormenta ',
#  'el pelotudo novio prometio si rescaba iba comprar chocolates ahora no va  llueve  morite chau ',
#  'eliminame bloqueame todo quieras pero enviaste tus nude desnude no hay     rayos  ',
#  'la lluvia estrellas mensaje gusta no va llegar nunca ',
#  'no diooooos bajo vago dios baranda tenia viejo  minimo lluvia lpm olor concha hermana ',
#  'semana lluvias mejor paraguas refugiarnos      ',
#  'se viene tormenta  chau punto chau clasico parece     ',
#  'amo  lluvia hacer todo gusta hacer   ',
#  'uuuy  calle   jaaa  sufran yo sufro siempre llueve caretas ',
#  'q placer escuchar truenos ',
#  'adentro llueve parece nunca va parar  ',
#  ' villamaria       hs        min              max                hum      viento     n  pres       lluvia     ',
#  'mundo basta truenos ',
#  'lluvia domingos  voy deprimir ',
#  '  intento  pero si llueve quedo casita sorry querida sol ',
#  '  climarafaela          hum        bar         lluvia    viento      ',
#  ' climarafaela          hum        bar          lluvia    viento      ',
#  'aaa puse manija joda  toda ropa prima rayos ',
#  ' fuertes lluvias tormentas afectaran zona durante  horas  algunas presentando fuerte intensidad siendo  fundamentalmente abundante  agua cortos     intensa actividad  ocasional  granizo  ',
#  'tornado sta fe keeee ondaaaa ',
#  'para todos piteaban lluvia  fue mejor ',
#  'tercer lunes llueve  ',
#  'la lluvia atenta contra probabilidad aprobar finales ',
#  '      rayos  ',
#  'no tormenta truena  no tormenta relampaguea  ella novia gorrea  ',
#  'lluvia chota  nos  salida ',
#  ' tormenta  tendedero   ropa tirada  reposera rota   agua patio  molino metido limonero maceta patio  entrada  toda rota  tampoco tenemos internet cable  ',
#  ' villamaria       hs        min              max                hum      viento     e  pres       lluvia      ',
#  'lpmmmm hermosa nuestra naturaleza       cosa  ver rayos cielo  ',
#  'mira  cuida lugares lluvia  micaelaa amoo   ',
#  'lluvia forra aburro quiero hacer algo hija puta ',
#  'hermosa lluvia faltar  no cierto tengo prueba  ',
#  'que lindo siente lluvia pieza  pero hoy    ',
#  'fooo loco  recen pare lluvia  tengo ir pelu ',
#  'no llueve no llueve no llueve no llueve no llueve no llueve no llueve no llueve no llueve no llueve  ',
#  'tenemos lluvia rato ',
#  'y si llueve     ',
#  'la lluvia obra paralizada formaron laguna  aislados vecinos paso picada    ',
#  ' rosarioar viernes              tormentas aisladas  tarde noche  mejorando  ',
#  'este  rompi   veces pantalla celular  llueve sopa salgo calle tenedor ',
#  'algo mas lindo dormir lluvia  ',
#  'amo dias  ',
#  'amo caminar bajo  ',
#  'no  nuevo sin lluvia ',
#  'creo mas lindo fue ver lluvia estrellas mis amigas ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'me  hoy tormenta ahora vecino gritando vamos bokeee  buen  ',
#  'densa lluvia ',
#  'que linda tormenta viene ',
#  'el viento fresco lluvia  ',
#  'hola  hoy   am vallamos cualquier lugar ver lluvia estrellas juntxs    ',
#  'que cosa linda estar tirada cama escuchando llueve  ',
#  'con lluvia ahrrrrr ',
#  'lo  lindo lluvia tengo   ',
#  'que hermoso entrenar  ',
#  'triunfo pechito bajo lluvia china  toyota     maria   mike conway kamui kovayashi fue vencedor   hs shanghai delante otro auto equipo  carrera epica bajo lluvia fue interrumpida     ',
#  'no uso pedo usan llevarme escuela  lluvia   ',
#  ' verga  era joda tomo pecho lluvia ',
#  '           pobres    culpa tormenta mierda  pobrezacero chamuyo  gobierno nefasto   uca ',
#  'gracias lluvia  pero hoy no necesito ',
#  'con lluvia  solo mates tortas fritas    ',
#  'el desopilante relato tormenta    ',
#  'lo faltaba  agarrre lluvia short  buen lunes hente ',
#  '   avisos hasta momento puede haber lluvias norte       centro sur  despejado        ero  tormentas aisladas centro norte   bastante inestable  temperaturas  templadas calurosas  prox act          ',
#  'vivir piso    tormenta no deseo nadie  tkm ',
#  ' santafe  datos lluvia  hasta        palacio municipal        alto verde        hospital        cic facundo              registraron  viento  fuerte        sector ',
#  'datos actuales  santafe barrio candioti norte                          lluvia hoy     ',
#  ' tormenta siempre sale sol    ',
#  'espero noche tormenta no decepcione  ',
#  ' llueve  ella tan cargosa   ',
#  'esta tormenta  ',
#  'llueve justo cuando tengo salir  esa suerteee ',
#  ' abajo lluvia    cuadras venir tomar colectivo  vine crocs no mojar zapatillas      encima     colectivo  todo  ',
#  'q lindo verlo todo cagado porq viene tormenta feminista encima  hizo    ',
#  'cierro pieza llaves porque hermano roba indumentaria ende nadie puede entrar cerrar ventana deje abierta  inundacion debe haber ni quiero saberlo  ',
#  'esta lluvia culiada no quiere parar    ',
#  'el aire ruido lluvia vuelvo looooooooooca ',
#  ' terrrrible tormenta viene  eso  ser salada  ',
#  '  soleado     poca probabilidad lluvia ',
#  ' villamaria       hs        min              max                hum      viento     no  pres       lluvia     ',
#  'tengo ganas comer algo dulce casa no hay nadie encima llueve salir comprar algo ',
#  ' jaaaaaaaa  lluvia  tormenta terror     viento truenos  todo     pero dormir ruido lluvia fondo    glorioso  ',
#  'con lluvia todo salimos primeras   ',
#  ' lluvia nuestra       ciudad                       turquina      norte    pereira zona rural           ',
#  'me lloraba gritos  calmarlo ahora creo si agarra tornado ni importa   sonnnnnn ',
#  'calmara lluvia  ',
#  'a  perro estaba dando miedo tormenta deje dormir pieza  acaba tirar pedo vi cara dios    respeto bondad ',
#  'no puede ser  pleno diciembre toca    sol    lluvia    nublados        sol    lluvia    carne    choclo    choclo    carne    carne    choclo    carne ',
#  'como cuando llueve automatico siempre tengo ir dormir ',
#  'vos  linda siempre  problemas ojeras  aunque pasen cosas feas  aunque persona  no quiera  aunque seas desastre dentro tormenta fuera   linda siempre  porque tus  no conocen fronteras  ',
#  'tormentas fuertes severas varias provincias centro    ',
#  'era perfecto dia pero lluvia arruino ',
#  'le acabo tirar  rayo perinizador  mucha gente vaya estoy acertando  ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'amo dias  ',
#  'se viene linda tormenta yo yendo inscribirme facultad ',
#  'si  hermoso   lluvia  ',
#  'me pone muy mal humor  lluvia orto arruine planes    ',
#  'que lindo volver caminando casa lluvia ',
#  'me encantan noches lluvia  sobre todo cuando no trabajo  siguiente     ',
#  'noche lluvia mas mates raspaditas  felicidad ',
#  'fotos tormenta    dic        sin filtro    regalo naturaleza    villa trinidad  santa fe  argentina  ',
#  ' lindo vientito olor  ',
#  'tres semanas agarra lluvia   salgo paraguas sol    grados ',
#  'toda  semana esperando ida bs as llueve lpm ',
#  ' minivoley ayer mini  lluvia mas      as vivieron hermosa jornada     argentina  ',
#  'amigo no puede gustar  tormentas yo  flotante ver todos rayos  viento  agua    ',
#  'ayuda difuminar cicatrices  eliminar  imperfecciones granitos   funciona barrera natural proteger piel rayos solares    vitamina e espectacular antioxidante protege          ',
#  'lluvia  ',
#  'que lluvia orto espero drene bien bombonera ',
#  'que linda lluvia     seria    noche si estuvieses aca migo  ',
#  'el crack  guitarra tarde hermosa lluvia nos dio   mas puedo pedir    ',
#  'igual altas ganas volver cuando  pleno auge tipo            era andar todos    viento  lluvia  hielo   haya ',
#  ' veces lluvias solo mojan    fuerte esos   salir tumba no tener  cualquier yugo no fuera   ',
#  'ni ganas ir colegio lluvia ',
#  'la siesta campo  lluvia  algo   ',
#  'lluvia estrellas male sal ',
#  'lluvia  siesta  mejor convinacion  ',
#  'que linda  lluvia   estudiar rendir    seguidos cabecear bala ',
#  'robaron moto barrio  fue cenar casa suegro   honda tornado afuera sustrajeron   ',
#  'datos actuales  santafe barrio sgto  cabral                         lluvia hoy      ',
#  'que hermosa lluvia dormir  ',
#  'unas ganas ver lluvia estrellas fernet mano  ',
#  'llueve lindo mucho   creo lluvia viene persiguiendo  conmigo cba nqn  inversa  nqn cba ',
#  'la vez van empezar llueve lpm ',
#  'truenos chotos ',
#  ' volvamos tarantela anoche bajo lluvia ',
#  'lo bueno toda lluvia no vamos correr gym  ',
#  ' calor  devuelvanme  grises   lluvia favor  ',
#  ' instalado hasta abril       lluvias        maiz  soja  ',
#  'buen  viernes tormentas   ',
#  'yo quisiera tomar sol cualquier persona pero trabajo toda tarde domingos no trabajo  nublado defecto llueve ',
#  'que lluvia puta ',
#  ' no indignan lluvia indignan calles rebalsadas agua no obras  hacen nadie dijo no hay hambre  ',
#  'lluvia lindooo    ',
#  'gente consejo no agarrar descalzo nada sea   cuando hay tormenta  pueden quedar yo   saludos  ',
#  'gracias dios poco sol tanta gente pasando mal lluvia   tengan hermoso    ',
#  'dormirse escuchando lluvia tendria considerarse octava maravilla mundo  ',
#  'que   lluvia dicen ',
#  'por ahora tengo ir entrenar llueve   ',
#  'mira  lindos rayos caiga uno frente ',
#  'despues lluvia siempre sale sol  dicen  ',
#  '       grados mis    llueve  bueno gracias igual ni  hacer joda ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  'norte san luis  cien familias lafinur afectadas destrozos  tormenta   ',
#  'tranquila mama tormenta  ',
#  'ya acercan especiales lavecchia no vi planeta gol todo   rayos ',
#  ' favor   hace      tormenta  barro desniveles calle  justo frente    viernes siguientes barren calles barrio saltean amancio alcorta  cuadra       barro  pudriendo  mucho olor  ',
#  'el clima parece estabilidad emocional  llueve rato  sale sol  cuando menos esperas larga toda  asi sucesivamente ',
#  '   lluvia tremenda pero cortita     minutos  ',
#  'vola alto suru  tranquilidad saber estas llegando paz   lluvia  esa tranquilidad vas estar paz  vas ser estrella  brillante cielo  hasta siempre  ',
#  'lo peor todo no lluvia    lindo calorrrrrrrrrr va venir despues ',
#  'y si venis dormimos ventana abierta mientras llueve  ',
#  'esta tormenta porque mande algo candela  ',
#  'y yo iba ir area  linda lluvia ',
#  ' villamaria       hs        min              max                hum      viento      ne  pres       lluvia     ',
#  'bueh    todos escucharon  trueno yo ni   ',
#  'me  tener perro  solo poder sacarlo pasear hora  lluvia td  ',
#  'llueve    dan ganas estar cama quiero matar ',
#  'que verga  lluvia loco ',
#  ' iba caer cielo ni arranco lluvia    ',
#  'la puta  lluvia culiada  activo casa   ',
#  ' intenta poniendo sonidos lluvia cosas asi ',
#  ' tormentas  ',
#  '    jueves             tormentas  prob  lluvias       viernes             parc  soleado  prob  lluvias        hora            climacordoba ',
#  '   pero no  si era trueno  ',
#  'que lindo ser imparcial  mismo cualquier resultado  lluvia ponga riesgo final entre dos equipos viven cagando resto clubes  acomodan arbitros  fechas  horarios    ',
#  'uh viene verdsdera tormenta lindo siiiiiiii ',
#  '  agvnet          hum        bar         lluvia    viento   nne  ',
#  'quien puede dormir mal escuchando sonidito lluvia    amo  ',
#  ' venite casa ver lluvia amor ',
#  ' rayo gay   ',
#  'alguien mas escucho trueno mas groso vida madrugada  ',
#  'la fuckin  primavera tormentas estilo   ',
#  'producto lluvia mujer      accidente vial  conductora  ford fiesta fue trasladada complejo sanitario san luis    ',
#  'por dios esos truenos lpm ',
#  'chicos voy ir poner carpa gitanos colectividades ver si  nos dejamos joder tanta lluvia yo quiero bailar  ',
#  'esta lluvia  xdiosss ',
#  ' agvnet          hum        bar         lluvia    viento     so  ',
#  'boe tormenta  no tengo ganas irme abajo dormir ',
#  ' frida  tranquila total llueve no puedo lavar ropa   ',
#  'con lluvia ta hacer todo  ',
#  'mi novio  porq tengo miedo truenos  ',
#  'hola  venir casa       diciembre mirar lluvia estrellas  enviar ',
#  ' si aja ver lluvia estrellas ',
#  ' keee  oh rayos  dije    ',
#  'lluvia ortoo ',
#  'mi tio  invito ver lluvia estrellas campo genio puso      ',
#  ' protector solar aerosol hidratante provee  alta frente  rayos uv    enriquecida  hialuronico origen natural    acuoso  sudor      ',
#  'anoche vi estrella fugaz casualidad  porque ni acordaba era lluvia estrellas    trajo tantos recuerdos veranos pasados  horas horas amigos campo mirandolass  ',
#  'nada mas lindo dormir siesta lluvia  ',
#  'son casi llueve  necesito vuelva abrir super  compro pan dulce  malo tan vagos estos chinos     aparecen  ',
#  'no dan idea miedo tengo viajar tormenta novio quiere vaya  chicxs  si sucede algo  ya saben  ',
#  'la lluvia bell ville viniendo  ',
#  'linda tormenta viene ',
#  'tranquilo tormenta   ',
#  'queres ver lluvia estrella conmigo  mientras comemos boludeces hablamos vida   enviar  ',
#  'que cosa linda tormentas ',
#  'se viene lluvia linda dormir ',
#  '  entrar twitter  rayos ',
#  'miren llueve yo tengo ir trabajar  feo crecerrrr ',
#  'otro nacional mardel  otra vez hace  llueve  ',
#  'que piola estan truenos ',
#  'lluvia  huevos dos paquetes yerba  ',
#  'rayos  ',
#  '  lluvia he  ',
#  'si  llueve  mariachi mando dos besitos ',
#  'con lluvia  pollerear juntos   ni caza seguro  ',
#  ' municipalidad no paga  hicieron casa      ',
#  'tormenta facha quisiste decir    ',
#  'alta tormenta yo  ',
#  'pero hermoso  lluvia dormirlo completo   tengo seguir estudiando  ',
#  '  luchona  tormenta  buscar ropa soga  macrisis no  bancar vuele ropa   ',
#  'estoy viendo  medio transporte voy trabajar  dudo si tomo     agarro alguna canoa porque  todo inundado  ',
#  ' hace  lluvia delfina   camukis  ',
#  'llueve    min sale   sol   hermosa humedad  ',
#  'hola  venir cucharear toda noche mientras escuchamos truenos  enviar ',
#  'que lindo cuando llueve tenes faso ',
#  'laaa tormenta va venir  puse estudiar     ',
#  ' nos roban hasta lluvia   ',
#  'este   hermoso escucharlo  lluvia crazy pibes ',
#  'que enfermitos salen lluvia calle  menos trabajan  ',
#  'linda tormenta viene  ',
#  'lluvia solo quiero decirte amo ',
#  'datos actuales  santafe barrio  norte                          lluvia hoy      ',
#  'hoy no puse lavar ropa porque dio paja obvio   anunciado lluvia   ser ama casa ',
#  'me  primera final suspendieron lluvia  sean serios definan  si van suspender   dejo tomar cerveza pedo  ',
#  'que lindo dormir lluvia  tremenda paz genera ruido  ',
#  ' lluvia calor  protagonistas    precipitaciones toda jornada         ',
#  'aaaaa lluvia amooooo ',
#  'quiero salir jugar  pokemongo pero llueve tengo estudiar  ',
#  ' chulu si llueve  ',
#  'estoy pique si llueve estoy horno ',
#  'esta lluvia mierda no quiere paraaaaaaar lluvia mierda no quiere paraaaaaar gallinaaaaaaa no paran lloraaaaaaar ',
#  'queres venir ver lluvia estrellas conmigo   ',
#  '  estudio  llueve fe dios nv ',
#  'ponerse limpiar patio rayo sol otra manera fea empezar  ',
#  'me explota cabeza  seguro no porque estuve   horas rayo sol     birras medio ',
#  'voy cargar cel antes epe corte tormenta ',
#  'en  casa llega pasar tormenta pasando todos lados tengo ir buscar galpones colon mas menos ',
#  ' lindo  estar casa mirando lluvia mates tortas fritas  ',
#  'zarpada tormenta   cordoba ',
#  'si no mandaron esquina ver si llueve  fracasaste incha pelotas ',
#  'lluviaaaaa tus besos frios lluvia ',
#  'que lluvia orto loco ',
#  'salimos correr  viento tormenta  ya fue mundo quiere casa     kilos helado netflix ',
#  'el tiempo  santa fe  barrio constituyentes                         lluvia hoy      ',
#  ' mmm parece  tormenta va rato che  ',
#  'lo  cerca estuve muerte fue recien cuando viento  puerta  encima  lpm  toda panza pierna   ',
#  '  atentosaltiempo calles inundadas zonas anegadas luego fuerte temporal lluvia  rosario    casi     poco  media hora  hay denuncias     ramas   ',
#  'hermosa lluvia  ',
#  'que locura caminar  escabio bajo lluvia   gracias tanto amigos  ',
#  'la   no generar  duelos   ahora match entre movileros   lluvia  todo  no  i    ',
#  'linda tormenta tener novia ',
#  'fp   addiriyaheprix bajo lluvia     sobre  gen    suspenderse  abbformulae  formulae  fanboost  josemarialopez  ',
#  'la puta lluvia queremos tomar sol ',
#  ' desastre baires todo inundado     sierras  caer cfk punta  ',
#  'primero  calor   calor empezaron quejar  ahora llueve quejan lluvia pero manga boluudoooos ',
#  ' cola llueve xdxdxd ',
#  '   lavar auto llueve      ',
#  'esquina amigos  ',
#  'me hacer todo tipo peinado  pero ninguno queda bien vestido  rayos  ',
#  'con lluvia dormir ',
#  ' golpista    ya veo lluvia twitts esa   guardo pero no juegues ilusiones muy sensible ',
#  'anoche  viernes  nos  hermosa lluvia  ',
#  '  sabjusto  santafe  inundaciones  tormentas  lluvias    ',
#  '  buenas condiciones  nubosidad variable fresco   inestable sobre noche probables lluvias          pronosticodeltiempo  tiempo  rosario  somosrosario  ',
#  'que hermosa lluvia ',
#  'caen rayos desde ayer yo  todo enchufado casa  temo televisor amado lavarropas  ',
#  'me asustaron tormenta manga giles  ',
#  ' agvnet          hum        bar          lluvia    viento      ',
#  'faa mal ahi lluvia  ahora seco  ',
#  'lluvia mierdaa ',
#  ...]

# %%
'hola'.encode('unicode-escape').decode('ASCII').isascii()
# Out:
# True

# %% [markdown]
# #### División en datasets de  _train_ y _test_

# %%
size = 0.8

## Toma los tweets, los asocia con su tag y luego los divide en cada una de las palabras que los componen
## zip() itera tuplas

train = [(i.split(),j) for i,j in zip(list(msj)[1:int(len(msj)*0.8)],list(TAG)[1:int(len(msj)*0.8)])]

test = [(i.split(),j) for i,j in zip(list(msj)[int(len(msj)*0.8)+1:len(msj)],list(TAG)[int(len(msj)*0.8)+1:len(msj)])]

## Guardo los labels, (en este caso 1 y 0) en un diccionario
label_to_ix = { 1: 0, 0: 1 } 

# 1 = Meteorológico
# 0 = No meteorológico

# %% [markdown]
# #### Generación del diccionario con el dataset completo

# %%
word_to_ix = {}

# El diccionario tiene que tener todas las palabras posibles
datos = train + test

## Cada palabra que encuentra la guarda en un diccionario
for sent, _ in datos:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

VOCAB_SIZE = len(word_to_ix)
NUM_LABELS = 2

# %% [markdown]
# #### Bag of Words

# %%
class BoWClassifier(nn.Module): # inheriting from nn.Module!
    
    def __init__(self, num_labels, vocab_size):
        
        super(BoWClassifier, self).__init__()

        self.linear1 = nn.Linear(vocab_size, 100)
        self.linear2 = nn.Linear(100, num_labels)
        
        
    def forward(self, bow_vec):
        
        h = self.linear1(bow_vec)
        
        y = self.linear2(h)
        
        soft = F.log_softmax(y , dim=1)
        
        return soft
    
    def make_bow_vector(sentence, word_to_ix):
        vec = torch.zeros(len(word_to_ix))
        for word in sentence:
            vec[word_to_ix[word]] += 1
        return vec.view(1, -1)

    def make_target(label, label_to_ix):
        
        return torch.LongTensor([label_to_ix[label]])

# %% [markdown]
# #### Miremos la frecuencia de ocurrencia de palabras en el diccionario

# %%
vec = torch.zeros(len(word_to_ix))
for i, label in test+train:
    bow_vector = BoWClassifier.make_bow_vector(i, word_to_ix)
    vec = vec.add(bow_vector)

vec=vec[0].tolist()

# %%
## Genero un dataframe que me pemite ordenar de mayor a menor respecto de la columna Frecuencia
tot = pd.DataFrame()
tot['Diccionario'] = list(word_to_ix.keys())
tot['Frecuencia'] = vec
tot['Num'] = word_to_ix.values()
tot = tot.sort_values(by=['Frecuencia'], ascending=False)

# %% [markdown]
# ### Entrenamiento

# %%
model = BoWClassifier(NUM_LABELS, VOCAB_SIZE)
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Se suele usar la cantidad de epocas que lleve a la estabilidad sin overfitear

error = []

for epoch in range(50):
    if epoch % 10 == 0: print('Epoch: %i' %epoch)
    for instance, label in train:
        
        
        # Hay que resetear los gradientes antes de hacer cuentas
        model.zero_grad()
    
        # Hacemos el vector de bag of words
        bow_vec = BoWClassifier.make_bow_vector(instance, word_to_ix)
        
        # Guardamos el label del diccionario de Tags
        target = BoWClassifier.make_target(label, label_to_ix)
    
        # Hacemos el forward pass.
        log_probs = model(bow_vec)
    
        # Calculamos el error
        loss = loss_function(log_probs, target)
    
        # Le pedimos a torch que busque los gradientes con back propagation
        
        loss.backward()
        
        # Usamos SGD para hacer back propagation y modificar los pesos
        optimizer.step()
    error.append(loss) 

   
plt.figure()
plt.plot(error)
plt.show()
# Out:
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40

# %% [markdown]
# ## Usamos los twits de test para verificar

# %%
c = [0,0,0,0]
for instance, label in test:
    bow_vec = autograd.Variable(BoWClassifier.make_bow_vector(instance, word_to_ix))
    log_probs = model(bow_vec)
    log_probs_exp = log_probs.exp()
    if bool (log_probs_exp[0][0]>0.5):
        
        if label == 1: 
            c[0]+=1
           # print ('\033[1;93m' , log_probs_exp , label)
        else: 
            c[2]+=1
           # print ('\033[1;31m' , log_probs_exp , label)

    elif bool (log_probs_exp[0][1]>0.5):
        
        if label == 0:
            c[1]+=1
           # print ('\033[1;32m' , log_probs_exp , label)
            
        else:
            c[3]+=1
           # print ('\033[1;66m' , log_probs_exp , label)


print('\033[0m Aciertos a tweets meteorológicos:', round((c[0]/sum(c))*100, 3),
      '% \n Aciertos a tweets no meteorologicos:', round((c[1]/sum(c))*100, 3),
      '% \n Sorpresas: ', round((c[3]/sum(c))*100, 3),
      '% \n Falsos positivos: ', round((c[2]/sum(c))*100, 3), '%') 
print(c)
#print ('\033[0m', next(model.parameters())[:,word_to_ix["lluvia"]]) # Index corresponding to Spanish goes up, English goes down!
# Out:
#  Aciertos a tweets meteorológicos: 36.544 %
#  Aciertos a tweets no meteorologicos: 21.53 %
#  Sorpresas:  14.448 %
#  Falsos positivos:  27.479 %
# [129, 76, 97, 51]

# %%
word_to_ix
# Out:
# {'quiero': 0,
#  'ir': 1,
#  'centro': 2,
#  'pero': 3,
#  'seguro': 4,
#  'llueve': 5,
#  'si': 6,
#  'mucho': 7,
#  '\\U0001f612': 8,
#  'hago': 9,
#  '\\U0001f917': 10,
#  'hasta': 11,
#  'cuando': 12,
#  'voy': 13,
#  'seguir': 14,
#  'teniendo': 15,
#  'miedo': 16,
#  'tormentas': 17,
#  '\\U0001f644': 18,
#  '\\U0001f623': 19,
#  'climarafaela': 20,
#  'hum': 21,
#  'bar': 22,
#  'lluvia': 23,
#  'viento': 24,
#  'sso': 25,
#  'sea': 26,
#  'estacion': 27,
#  'no': 28,
#  'hay': 29,
#  'plata': 30,
#  'ahora': 31,
#  'cambia': 32,
#  'tenes': 33,
#  'estudiar': 34,
#  'igual': 35,
#  'tengo': 36,
#  'internet': 37,
#  'espera': 38,
#  'tremenda': 39,
#  'tarde': 40,
#  'que': 41,
#  'linda': 42,
#  'noche': 43,
#  '\\U0001f496': 44,
#  'miercoles': 45,
#  'calor': 46,
#  'previo': 47,
#  'lluvias': 48,
#  'me': 49,
#  'gusta': 50,
#  'porque': 51,
#  'parece': 52,
#  'estan': 53,
#  'fritando': 54,
#  'empanadas': 55,
#  'puesgorda': 56,
#  '\\U0001f602': 57,
#  'noviembre': 58,
#  'sin': 59,
#  'ti': 60,
#  'sentir': 61,
#  'dice': 62,
#  'llorando': 63,
#  'todo': 64,
#  'acabo': 65,
#  '\\U0001f3b5': 66,
#  'agvnet': 67,
#  'con': 68,
#  'dieron': 69,
#  'ganas': 70,
#  'cucharear': 71,
#  '\\U0001f60f': 72,
#  'y': 73,
#  'largo': 74,
#  '\\u2614': 75,
#  '\\U0001f495': 76,
#  'hermosa': 77,
#  'tormenta': 78,
#  'dan': 79,
#  'aseguran': 80,
#  'stock': 81,
#  'suficiente': 82,
#  'bengalas': 83,
#  'combatir': 84,
#  'aprobe': 85,
#  'final': 86,
#  'tome': 87,
#  'cervezas': 88,
#  'amigos': 89,
#  'estuve': 90,
#  'novio': 91,
#  'comi': 92,
#  'milanesa': 93,
#  'napolitana': 94,
#  'agua': 95,
#  'hirviendo': 96,
#  'estoy': 97,
#  'dormirme': 98,
#  'sabanas': 99,
#  'limpias': 100,
#  'fondo': 101,
#  'gato': 102,
#  'lado': 103,
#  'siento': 104,
#  'mas': 105,
#  'realizada': 106,
#  'pq': 107,
#  'sebastian': 108,
#  'levanto': 109,
#  'simpatico': 110,
#  'horrible': 111,
#  'eso': 112,
#  'asi': 113,
#  'mi': 114,
#  'padre': 115,
#  'van': 116,
#  'tener': 117,
#  'poner': 118,
#  'jugar': 119,
#  'yo': 120,
#  'mientras': 121,
#  'miro': 122,
#  'forma': 123,
#  '\\U0001f615': 124,
#  'buena': 125,
#  'pasaba': 126,
#  'clima': 127,
#  'donde': 128,
#  'salio': 129,
#  'onda': 130,
#  'sale': 131,
#  'sol': 132,
#  'tiempo': 133,
#  'loco': 134,
#  'lo': 135,
#  'hermoso': 136,
#  'dias': 137,
#  'ver': 138,
#  'otros': 139,
#  'humanos': 140,
#  'bicicleta': 141,
#  'buscando': 142,
#  'refugio': 143,
#  'plena': 144,
#  'poca': 145,
#  'alma': 146,
#  'bicicletera': 147,
#  'plan': 148,
#  'escuchando': 149,
#  'temas': 150,
#  'fasciolo': 151,
#  'ruido': 152,
#  'haciendo': 153,
#  'cucharita': 154,
#  'gata': 155,
#  'ne': 156,
#  'como': 157,
#  'hace': 158,
#  'mambear': 159,
#  'estaria': 160,
#  'venga': 161,
#  'dure': 162,
#  'villamaria': 163,
#  'hs': 164,
#  'min': 165,
#  'max': 166,
#  'ene': 167,
#  'pres': 168,
#  'dudas': 169,
#  'usted': 170,
#  'gobernador': 171,
#  'querido': 172,
#  'mejor': 173,
#  'piloto': 174,
#  'en': 175,
#  'santa': 176,
#  'fe': 177,
#  'adivinen': 178,
#  'quien': 179,
#  'mojo': 180,
#  'gracias': 181,
#  'gustado': 182,
#  'video': 183,
#  'temporada': 184,
#  'acerca': 185,
#  'fortnite': 186,
#  'battle': 187,
#  'royale': 188,
#  'recien': 189,
#  'despierto': 190,
#  'siesta': 191,
#  'duerme': 192,
#  'hubiera': 193,
#  'estado': 194,
#  'piola': 195,
#  'dormiamos': 196,
#  'juntos': 197,
#  'ahre': 198,
#  'sos': 199,
#  '\\U0001f60d': 200,
#  '\\u2014': 201,
#  'abran': 202,
#  'paraguas': 203,
#  'datos': 204,
#  'netflix': 205,
#  'perfeccion': 206,
#  'aaaaay': 207,
#  'boludo': 208,
#  'canso': 209,
#  'ojala': 210,
#  'pusiera': 211,
#  'mimosa': 212,
#  'pone': 213,
#  'gorda': 214,
#  'vieron': 215,
#  'cordoba': 216,
#  'gente': 217,
#  'estudiando': 218,
#  'bueno': 219,
#  'creo': 220,
#  'hacian': 221,
#  'tesis': 222,
#  'el': 223,
#  'barrio': 224,
#  'constituyentes': 225,
#  'hoy': 226,
#  'amo': 227,
#  'dormir': 228,
#  'man': 229,
#  'pase': 230,
#  'largooooo': 231,
#  'salir': 232,
#  'manga': 233,
#  'forros': 234,
#  'se': 235,
#  'rato': 236,
#  'otro': 237,
#  'patio': 238,
#  'escuchar': 239,
#  'truenos': 240,
#  'dolby': 241,
#  'surround': 242,
#  'lea': 243,
#  'estacionplus': 244,
#  'anuncian': 245,
#  '\\': 246,
#  'entre': 247,
#  'rios': 248,
#  'fin': 249,
#  'advierten': 250,
#  'fenomenos': 251,
#  'meteorologicos': 252,
#  'alto': 253,
#  'impacto': 254,
#  'proximos': 255,
#  'empezara': 256,
#  'lluvioso': 257,
#  'mira': 258,
#  'informe': 259,
#  'especial': 260,
#  'provincia': 261,
#  'region': 262,
#  'encima': 263,
#  'lindo': 264,
#  'andar': 265,
#  'bajo': 266,
#  'feo': 267,
#  'departamento': 268,
#  '\\U0001f62d': 269,
#  'actuales': 270,
#  'santafe': 271,
#  'candioti': 272,
#  'norte': 273,
#  'uno': 274,
#  'placeres': 275,
#  'vida': 276,
#  '\\U0001f49e': 277,
#  'nomas': 278,
#  'tema': 279,
#  'depende': 280,
#  'complejidad': 281,
#  'quiera': 282,
#  'darle': 283,
#  'archivo': 284,
#  'solo': 285,
#  'fotos': 286,
#  'videos': 287,
#  'paso': 288,
#  'data': 289,
#  'lpm': 290,
#  'corta': 291,
#  'luz': 292,
#  'cada': 293,
#  'wos': 294,
#  'cacha': 295,
#  'trueno': 296,
#  'etc': 297,
#  'estaban': 298,
#  'quinto': 299,
#  'dtoke': 300,
#  'ya': 301,
#  'red': 302,
#  'bulls': 303,
#  'inter': 304,
#  'bestia': 305,
#  'hacer': 306,
#  'wacho': 307,
#  'sabemos': 308,
#  're': 309,
#  'xxl': 310,
#  'venia': 311,
#  'gym': 312,
#  'relajada': 313,
#  'cruza': 314,
#  'hombre': 315,
#  'corre': 316,
#  'vienen': 317,
#  'piedras': 318,
#  'cai': 319,
#  'podia': 320,
#  'ser': 321,
#  'posible': 322,
#  'empece': 323,
#  'correr': 324,
#  'por': 325,
#  'hdp': 326,
#  'bicicletear': 327,
#  'viendo': 328,
#  'dio': 329,
#  'culpa': 330,
#  'jeje': 331,
#  'dormi': 332,
#  'che': 333,
#  'agarre': 334,
#  '\\U0001f613': 335,
#  'vete': 336,
#  'aqui': 337,
#  'llego': 338,
#  'tan': 339,
#  'ansiada': 340,
#  '\\U0001f600': 341,
#  'alguien': 342,
#  'esos': 343,
#  've': 344,
#  'fue': 345,
#  'copada': 346,
#  'tiro': 347,
#  'arbol': 348,
#  'locoooooo': 349,
#  'a': 350,
#  'hora': 351,
#  'trabajar': 352,
#  'locos': 353,
#  'camilo': 354,
#  'aldao': 355,
#  'viejo': 356,
#  'cae': 357,
#  'rayo': 358,
#  'haganse': 359,
#  'favor': 360,
#  'mirar': 361,
#  'cielo': 362,
#  'belleza': 363,
#  'casi': 364,
#  'estrellas': 365,
#  'lleno': 366,
#  'los': 367,
#  'ancohe': 368,
#  'desperte': 369,
#  'primero': 370,
#  'pense': 371,
#  'oigan': 372,
#  'muchaho': 373,
#  'ecucharon': 374,
#  'rempalago': 375,
#  'mente': 376,
#  'matada': 377,
#  'larga': 378,
#  'fijar': 379,
#  'tuit': 380,
#  'motiva': 381,
#  'nada': 382,
#  'estamos': 383,
#  'epoca': 384,
#  'nos': 385,
#  'chupa': 386,
#  'huevo': 387,
#  'importa': 388,
#  'cagarnos': 389,
#  'esfuerzo': 390,
#  'hacen': 391,
#  'persona': 392,
#  'sienta': 393,
#  'total': 394,
#  'bien': 395,
#  'resto': 396,
#  'parta': 397,
#  'saben': 398,
#  'yendo': 399,
#  'colegio': 400,
#  'dato': 401,
#  'caida': 402,
#  'gualeguay': 403,
#  'ssssshhh': 404,
#  'deja': 405,
#  'tranquila': 406,
#  'vamos': 407,
#  '\\U0001f61d': 408,
#  'ta': 409,
#  'desmayarse': 410,
#  'canchas': 411,
#  'admirable': 412,
#  'tanta': 413,
#  'algunos': 414,
#  'campos': 415,
#  'impecables': 416,
#  'cabeza': 417,
#  'concha': 418,
#  'madre': 419,
#  '\\U0001f327': 420,
#  'imagen': 421,
#  'satelital': 422,
#  'muestra': 423,
#  'gran': 424,
#  'frente': 425,
#  'abarca': 426,
#  'sur': 427,
#  'noreste': 428,
#  'buenos': 429,
#  'aires': 430,
#  '\\u2600': 431,
#  'despejado': 432,
#  'zonas': 433,
#  'productoras': 434,
#  'veo': 435,
#  'va': 436,
#  'largar': 437,
#  'llover': 438,
#  'salga': 439,
#  'casa': 440,
#  'volviendo': 441,
#  'odiaaa': 442,
#  '\\U0001f926': 443,
#  '\\U0001f3fc': 444,
#  'n': 445,
#  'estar': 446,
#  'peliculas': 447,
#  'ay': 448,
#  'quiere': 449,
#  'parar': 450,
#  '\\U0001f649': 451,
#  'ke': 452,
#  'culiadaw': 453,
#  'un': 454,
#  'dia': 455,
#  'bello': 456,
#  'desatar': 457,
#  'nuestra': 458,
#  'tronar': 459,
#  'dolor': 460,
#  'maldigo': 461,
#  'veredas': 462,
#  'hechas': 463,
#  'mierdas': 464,
#  'momentos': 465,
#  '\\U0001f620': 466,
#  '\\U0001f611': 467,
#  'brasil': 468,
#  'grados': 469,
#  'mirandote': 470,
#  '\\U0001f31d': 471,
#  'para': 472,
#  'anduve': 473,
#  'klx': 474,
#  'prenderla': 475,
#  'fuego': 476,
#  'tornado': 477,
#  'electrica': 478,
#  'calcada': 479,
#  '\\U0001f624': 480,
#  'pedido': 481,
#  'solidario': 482,
#  'afectados': 483,
#  'llega': 484,
#  'facha': 485,
#  'parana': 486,
#  'abrazada': 487,
#  'domingo': 488,
#  'bajon': 489,
#  'arranque': 490,
#  'lunes': 491,
#  'media': 492,
#  'limitarme': 493,
#  'vivir': 494,
#  'madrugada': 495,
#  'parte': 496,
#  'tierra': 497,
#  'esto': 498,
#  'san': 499,
#  'luis': 500,
#  'tendria': 501,
#  'buscar': 502,
#  'ropa': 503,
#  'promo': 504,
#  'caminando': 505,
#  'v': 506,
#  'fast': 507,
#  'furious': 508,
#  'puede': 509,
#  'hubo': 510,
#  'esa': 511,
#  'cancha': 512,
#  'recuerdo': 513,
#  'campeon': 514,
#  'finalcopalibertadores': 515,
#  'bocavsriver': 516,
#  'conmebollibertadores': 517,
#  'estudiofutbol': 518,
#  'lamejorfinalensc': 519,
#  'menos': 520,
#  'espero': 521,
#  'nublado': 522,
#  'aguanto': 523,
#  'frio': 524,
#  '\\U0001f60a': 525,
#  'azul': 526,
#  '\\U0001f631': 527,
#  'celular': 528,
#  'solteras': 529,
#  'mtvemabiggestfansbts': 530,
#  'aerolineas': 531,
#  'segun': 532,
#  'idiota': 533,
#  'confirmado': 534,
#  'jacques': 535,
#  'cousteau': 536,
#  'era': 537,
#  'campora': 538,
#  'queria': 539,
#  'pileta': 540,
#  'serie': 541,
#  'ultimamente': 542,
#  'ni': 543,
#  'pasar': 544,
#  'chica': 545,
#  'corazon': 546,
#  'mundo': 547,
#  'balde': 548,
#  'unico': 549,
#  'viniendo': 550,
#  'de': 551,
#  'nuevo': 552,
#  'lloviendo': 553,
#  'siempre': 554,
#  'arruinando': 555,
#  'mis': 556,
#  'planes': 557,
#  'mierda': 558,
#  'rayos': 559,
#  '\\U0001f614': 560,
#  'real': 561,
#  'le': 562,
#  'puli': 563,
#  'bastante': 564,
#  'turra': 565,
#  '\\u2665': 566,
#  'maravilla': 567,
#  'gano': 568,
#  'belgrano': 569,
#  '\\U0001f914': 570,
#  'baradel': 571,
#  'tigre': 572,
#  'asamblea': 573,
#  'suteba': 574,
#  'tenga': 575,
#  'perrito': 576,
#  'rio': 577,
#  '\\U0001f923': 578,
#  'llueva': 579,
#  'escuela': 580,
#  'alta': 581,
#  'leche': 582,
#  'mia': 583,
#  '\\U0001f494': 584,
#  'las': 585,
#  'intensas': 586,
#  'generaron': 587,
#  'creciente': 588,
#  'siete': 589,
#  'metros': 590,
#  'antonio': 591,
#  'ingresa': 592,
#  'mucha': 593,
#  'fuerza': 594,
#  'cauce': 595,
#  'serranos': 596,
#  'luego': 597,
#  'varios': 598,
#  'afectan': 599,
#  'recomienda': 600,
#  'acatar': 601,
#  'ordenes': 602,
#  'defensa': 603,
#  'civil': 604,
#  'intentar': 605,
#  '\\u2026': 606,
#  'enfermaba': 607,
#  'so': 608,
#  'dando': 609,
#  'caen': 610,
#  'cercaaaa': 611,
#  'necesita': 612,
#  'chongo': 613,
#  'tiene': 614,
#  'entonces': 615,
#  'acuesta': 616,
#  'marina': 617,
#  'tambien': 618,
#  'junto': 619,
#  'mismo': 620,
#  'verdad': 621,
#  'feliz': 622,
#  'atardecer': 623,
#  'todos': 624,
#  'ustedes': 625,
#  'pisas': 626,
#  'baldosas': 627,
#  'flojas': 628,
#  'esperando': 629,
#  'familias': 630,
#  'ponen': 631,
#  'contentas': 632,
#  'gana': 633,
#  'copa': 634,
#  'equipo': 635,
#  'futbol': 636,
#  'andan': 637,
#  'contentos': 638,
#  'imagenes': 639,
#  'despues': 640,
#  'quedaron': 641,
#  'barrancas': 642,
#  'diamante': 643,
#  'diario': 644,
#  'abandono': 645,
#  'proyecto': 646,
#  'estabilizacion': 647,
#  'ejecuto': 648,
#  'zona': 649,
#  'puerto': 650,
#  'ultramar': 651,
#  'poqui': 652,
#  'verlo': 653,
#  'agusin': 654,
#  'anoche': 655,
#  'llegar': 656,
#  'mojado': 657,
#  'despeinado': 658,
#  'hizo': 659,
#  'cayeran': 660,
#  'babas': 661,
#  '\\U0001f63b': 662,
#  'amanecia': 663,
#  'insistencia': 664,
#  'primer': 665,
#  'impacte': 666,
#  'tus': 667,
#  'ojos': 668,
#  '\\U0001f621': 669,
#  'estando': 670,
#  '\\U0001f4a7': 671,
#  '\\u2601': 672,
#  '\\U0001f3e1': 673,
#  '\\U0001f44c': 674,
#  '\\u26bd': 675,
#  'pa': 676,
#  '\\u2764': 677,
#  '\\u26a0': 678,
#  'ojo': 679,
#  'avisa': 680,
#  '\\u201centro': 681,
#  'severa': 682,
#  'granizo': 683,
#  'mts': 684,
#  'alrura': 685,
#  'sobre': 686,
#  'ruta': 687,
#  'atencion': 688,
#  'ciudad': 689,
#  'sigue': 690,
#  '\\u201d': 691,
#  'mal': 692,
#  'amiga': 693,
#  'flashe': 694,
#  'pata': 695,
#  'embole': 696,
#  'maxima': 697,
#  'expresion': 698,
#  'desenchufen': 699,
#  'abuelo': 700,
#  'esta': 701,
#  'ideal': 702,
#  'cenar': 703,
#  'unos': 704,
#  'fideo': 705,
#  'salsa': 706,
#  'orgazmo': 707,
#  'calle': 708,
#  'traumo': 709,
#  'sorry': 710,
#  'levante': 711,
#  'clases': 712,
#  'pum': 713,
#  'jsksjsj': 714,
#  'saludos': 715,
#  'desde': 716,
#  'cama': 717,
#  '\\U0001f44b': 718,
#  'la': 719,
#  'capitulo': 720,
#  'pintando': 721,
#  'agarro': 722,
#  'toda': 723,
#  'bici': 724,
#  'tipo': 725,
#  'habia': 726,
#  'sido': 727,
#  'expulsado': 728,
#  'secundaria': 729,
#  'haber': 730,
#  'hecho': 731,
#  'caricatura': 732,
#  'profesor': 733,
#  'tuvo': 734,
#  'irse': 735,
#  'pais': 736,
#  'conseguir': 737,
#  'titulo': 738,
#  'estaba': 739,
#  'experimentos': 740,
#  'accidentalmente': 741,
#  'descubrio': 742,
#  'ndchances': 743,
#  'olor': 744,
#  'vas': 745,
#  'mojarte': 746,
#  'fuertes': 747,
#  'catamarca': 748,
#  'oeste': 749,
#  'santiago': 750,
#  'estero': 751,
#  'tucuman': 752,
#  'rendir': 753,
#  'todoooo': 754,
#  'inundado': 755,
#  'suerte': 756,
#  'manejo': 757,
#  'regalo': 758,
#  'durmiendo': 759,
#  'particular': 760,
#  'accionistas': 761,
#  'comieron': 762,
#  'viaje': 763,
#  'inversiones': 764,
#  'controlamos': 765,
#  'inflacion': 766,
#  'problema': 767,
#  'deuda': 768,
#  'dolares': 769,
#  'moneda': 770,
#  'maneja': 771,
#  'titiritero': 772,
#  'avion': 773,
#  'arriba': 774,
#  'asustes': 775,
#  'superliga': 776,
#  'patronato': 777,
#  'ruda': 778,
#  'mismas': 779,
#  'estuvieron': 780,
#  'empate': 781,
#  'union': 782,
#  'abril': 783,
#  'ingreso': 784,
#  'vestuario': 785,
#  'patron': 786,
#  'trabajo': 787,
#  'espectacular': 788,
#  'pile': 789,
#  'matessss': 790,
#  '\\U0001f475': 791,
#  '\\U0001f493': 792,
#  'madurar': 793,
#  'dejar': 794,
#  'tenerle': 795,
#  'hola': 796,
#  'insomio': 797,
#  'hernan': 798,
#  'hablo': 799,
#  'algo': 800,
#  'amigo': 801,
#  'hable': 802,
#  'sabados': 803,
#  'activarmelos': 804,
#  'bocha': 805,
#  'acostada': 806,
#  'esc': 807,
#  'quedarme': 808,
#  'libre': 809,
#  'orrrrto': 810,
#  'viene': 811,
#  'chanta': 812,
#  'canchitas': 813,
#  '\\U0001f60c': 814,
#  '\\U0001f64f': 815,
#  'orto': 816,
#  'necesidad': 817,
#  'verrrrrr': 818,
#  'finde': 819,
#  'justo': 820,
#  'nueno': 821,
#  'acuerdensen': 822,
#  'sgto': 823,
#  'cabral': 824,
#  'ahi': 825,
#  'tene': 826,
#  'pasa': 827,
#  'salen': 828,
#  'puedo': 829,
#  'todavia': 830,
#  'ayer': 831,
#  'entere': 832,
#  'nadie': 833,
#  'dijo': 834,
#  'haces': 835,
#  'poco': 836,
#  'hice': 837,
#  'tuco': 838,
#  'muy': 839,
#  'rico': 840,
#  'modesta': 841,
#  'veces': 842,
#  'riquisimo': 843,
#  'comida': 844,
#  'rica': 845,
#  'reprogramacion': 846,
#  'taburetes': 847,
#  'arte': 848,
#  '\\u2757': 849,
#  '\\u2757por': 850,
#  'pronostico': 851,
#  'subasta': 852,
#  'politecnico': 853,
#  'reprogramada': 854,
#  'proximo': 855,
#  'pecho': 856,
#  'xd': 857,
#  'cuenta': 858,
#  'fallar': 859,
#  'iba': 860,
#  'quejar': 861,
#  'tenia': 862,
#  'volver': 863,
#  'acorde': 864,
#  'sabado': 865,
#  'corrimos': 866,
#  'bobos': 867,
#  'cuadras': 868,
#  'calles': 869,
#  'inundadas': 870,
#  'contexto': 871,
#  'hermano': 872,
#  'am': 873,
#  'sujeto': 874,
#  'individuo': 875,
#  'toma': 876,
#  'cantidades': 877,
#  'bajas': 878,
#  'alcohol': 879,
#  'excepcion': 880,
#  'ola': 881,
#  'bb': 882,
#  'estas': 883,
#  'invitado': 884,
#  'solamente': 885,
#  'acostarnos': 886,
#  'darnos': 887,
#  'muchos': 888,
#  'besos': 889,
#  'enviar': 890,
#  'inverno': 891,
#  'cocino': 892,
#  'comio': 893,
#  'chocolate': 894,
#  'entero': 895,
#  'resultado': 896,
#  'dos': 897,
#  'inconveniente': 898,
#  'intensa': 899,
#  'basura': 900,
#  'interes': 901,
#  'general': 902,
#  'boluda': 903,
#  'chistoso': 904,
#  'dije': 905,
#  '\\u201clluvia': 906,
#  'oyes': 907,
#  'escuchas': 908,
#  'boludeando': 909,
#  'verdadera': 910,
#  'intendente': 911,
#  'reclamo': 912,
#  'impuestos': 913,
#  'laguna': 914,
#  'vez': 915,
#  'silva': 916,
#  'reconquista': 917,
#  'e': 918,
#  'iberlucea': 919,
#  'haga': 920,
#  'mks': 921,
#  'saco': 922,
#  'plus': 923,
#  'faltaba': 924,
#  'ultima': 925,
#  'fecha': 926,
#  'abuso': 927,
#  'quede': 928,
#  'odio': 929,
#  'cosa': 930,
#  'humor': 931,
#  'durante': 932,
#  'semana': 933,
#  'semanas': 934,
#  'secando': 935,
#  'remil': 936,
#  'malabia': 937,
#  'maria': 938,
#  'sanjusto': 939,
#  'llenas': 940,
#  'probabilidad': 941,
#  'salis': 942,
#  'afuera': 943,
#  'raja': 944,
#  'metereologico': 945,
#  'chupame': 946,
#  'maamaa': 947,
#  'veritas': 948,
#  'preocupada': 949,
#  'olvide': 950,
#  'cumplia': 951,
#  'tremendo': 952,
#  'cap': 953,
#  'prendio': 954,
#  'alarma': 955,
#  'auto': 956,
#  'paja': 957,
#  'sola': 958,
#  'estos': 959,
#  'cuchareando': 960,
#  'deberia': 961,
#  'maravillas': 962,
#  'pinte': 963,
#  'loca': 964,
#  '\\U0001f60b': 965,
#  'juega': 966,
#  'active': 967,
#  'joda': 968,
#  'juro': 969,
#  'cagada': 970,
#  'patas': 971,
#  'team': 972,
#  'rebellion': 973,
#  'racing': 974,
#  'dialogo': 975,
#  'radio': 976,
#  'lotterer': 977,
#  'termina': 978,
#  'preguntando': 979,
#  'tecnicos': 980,
#  'pit': 981,
#  'apuntando': 982,
#  'ademas': 983,
#  'insiste': 984,
#  'facil': 985,
#  'conducir': 986,
#  'condiciones': 987,
#  '\\U0001f302': 988,
#  'entender': 989,
#  'cockpit': 990,
#  'quieren': 991,
#  'decirme': 992,
#  'expiloto': 993,
#  'audi': 994,
#  'supercar': 995,
#  'hibr': 996,
#  'culia': 997,
#  'primera': 998,
#  'insoportable': 999,
#  ...}

# %% [markdown]
# ## Graficos de verificación

# %%
fig = plt.figure(figsize=(13,5))



opacity = 0.4
bar_width = 0.35


"""GRAFICO DE VERIFICACIÓN"""

ax = plt.subplot(1,2,1)

bar = plt.bar(range(4),c,
              tick_label=['Aciertos \n Meteorológico','Aciertos No \n Meteorológico',
                          'Falsos positivos','Sorpresas'], color = 'skyblue')
plt.title('Resultados')
plt.ylabel('Cantidad de aciertos.  Total='+str(sum(c)))
for rect, porcentaje in zip(bar,c):
    height = rect.get_height()- 5
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % round((porcentaje/sum(c))*100, 3) + ' %'
             ,fontsize = 13, color = 'black',ha='center', va='bottom')

  
"""GRÁFICO DE COMPARACIÓN PARA CADA TAG"""
    
ax2 = plt.subplot(1,2,2)

bar1 = plt.bar(np.arange(2), [c[0]+c[2],cant[1]+c[3]], bar_width, 
               tick_label = ['Meteorológicos', 'No Meteorológicos'],
               color = 'skyblue', label = 'Total de twits'
              )

for rect, porcentaje in zip(bar1,[c[0]+c[2],c[1]+c[3]]):
    height = rect.get_height()-20
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % porcentaje
             ,fontsize = 13, color = 'black',ha='center', va='bottom')


bar2 = plt.bar(np.arange(2) +bar_width, [c[3],c[2]], bar_width,
              tick_label = ['Meteorológicos', 'No Meteorológicos'],
               color = 'salmon' , label= 'Total de Fallas'
              )
for rect, porcentaje in zip(bar2,[c[3],c[2]]):
    height = rect.get_height()-20
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % porcentaje
             ,fontsize = 13, color = 'black',ha='center', va='bottom')

plt.legend()
plt.title('Comparativa')
# Out:
# Text(0.5, 1.0, 'Comparativa')
