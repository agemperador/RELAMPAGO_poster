# %% [markdown]
# # Detección de tweets meteorológicos con Bag of Words

# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Cargo la base de datos clasificada y genero las variables de importancia

# %%
TW = pd.read_csv('base_corr.csv')
MSJ = TW['Twit']
TAG = TW['Tag']
NUM = TW['Num']

# %% [markdown]
# ### Defino una variable cantidad que tiene la cantidad de tw de cada tipo

# %%
cant = [len (np.array(TAG) [np.where(TAG == 0)]) , len (np.array(TAG) [np.where(TAG == 1)])]

# %% [markdown]
# #### Elimino las cosas innecesarias de msj

# %%
def normalizacion(mensaje):
    
    mensaje = list(mensaje)
    lenght = len(mensaje)
    
    lista_ascii = [['\\xe1', '\\xe9', '\\xed', '\\xf3', '\\xfa', '\\xf1', '\\xd1', '\\xc1','\\xc9', '\\xcd', '\\xd3', 
                 '\\xda', '\\xa1', '\\xbf', '\\xdc', '\\xfc', '\\xb4', '\\xba', '\\xaa', '\\xb7','\\xc7','\\xe7',
                 '\\xa8', '\\xb0C', '\\n', '\\xb0c', '\\xbb', 'xb0', '\\ufe0f'],['a', 'e', 'i', 'o', 'u', 'ñ', 'Ñ', 'A', 'E', 'I', 'O', 'U', '', '', 'Ü', 'ü', '', 
                           ' ', '', '','Ç','ç','', ' ', ' ', ' ', ' ', ' ', ' ']]
    lista_simb = ['!','\'', '\"', "|", '$', "%", "&", "(", ")", "=", "?", "+",'/', ";", "_", "-", "1","2","3","4","5","6","7","8","9","0", '*',',', '.', ':', '#']
    
    ign_palabras = ['mbar','cdu','s','la','lo','st','que','este', 'me','t','p','el','weathercloud','en','h','temp','hpa','km','mm',"su","vos",'que',"re","xq","le","te","tu","soy","sos","mi","da","o","x","les","me","d","q", "como", "lo", "los", "mi", "son", "a", "el", 
                    "un","la", "una","en","por","para", 'las',"ante", "al", 'me',"rt", "del", "y", "se", "de", "que", "sus", "ha", "es", "con", "esta"]
    
    for i in range(lenght):
        
        ## Convierto mayúsculas en minúsculas
        mensaje[i] = mensaje[i].lower()
        
        ## Saco las menciones y otras cosas
        txt = mensaje[i].split()
        
        for j in range(len(txt)):
            if ('@' in txt[j]) and ('RELAMPAGO2018' not in txt[j]) and ('RELAMPAGO_edu' not in txt[j]) or ('jaj' in txt[j]) or ('https' in txt[j]): txt[j]=''
        
        mensaje[i] = " ".join(txt)
        
        ## Reemplazo símbolos
        for h in range(len(lista_simb)):
            mensaje[i] = mensaje[i].replace(lista_simb[h], ' ')
            
        ## Convierto el msj a ASCII, reemplazo los errores de decodificación y agrego un espacio antes de cada decodificación
        mensaje[i] = mensaje[i].encode('unicode-escape').decode('ASCII')+" "     
        
        for j in range(len(lista_ascii[0])):
            mensaje[i] = mensaje[i].replace(lista_ascii[0][j], lista_ascii[1][j])
        
        mensaje[i] = mensaje[i].replace('\\', ' \\')
        
        for j in range(len(ign_palabras)):
            mensaje[i] = mensaje[i].replace(" "+ign_palabras[j]+" ", ' ')
        
    return(mensaje)
msj = normalizacion(MSJ)

# %% [markdown]
# #### División en datasets de  _train_ y _test_

# %%
size = 0.8

## Toma los tweets, los asocia con su tag y luego los divide en cada una de las palabras que los componen
## zip() itera tuplas

train = [(i.split(),j) for i,j in zip(list(msj)[1:int(len(msj)*0.8)],list(TAG)[1:int(len(msj)*0.8)])]

test = [(i.split(),j) for i,j in zip(list(msj)[int(len(msj)*0.8)+1:len(msj)],list(TAG)[int(len(msj)*0.8)+1:len(msj)])]

## Guardo los labels, (en este caso 1 y 0) en un diccionario
label_to_ix = { 1: 0, 0: 1 } 

# 1 = Meteorológico
# 0 = No meteorológico

# %% [markdown]
# #### Generación del diccionario con el dataset completo

# %%
word_to_ix = {}

# El diccionario tiene que tener todas las palabras posibles
datos = train + test

## Cada palabra que encuentra la guarda en un diccionario
for sent, _ in datos:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

VOCAB_SIZE = len(word_to_ix)
NUM_LABELS = 2

# %% [markdown]
# #### Bag of Words

# %%
class BoWClassifier(nn.Module): # inheriting from nn.Module!
    
    def __init__(self, num_labels, vocab_size):
        
        super(BoWClassifier, self).__init__()

        self.linear1 = nn.Linear(vocab_size, 100)
        self.linear2 = nn.Linear(100, num_labels)
        
        
    def forward(self, bow_vec):
        
        h = self.linear1(bow_vec)
        
        y = self.linear2(h)
        
        soft = F.log_softmax(y , dim=1)
        
        return soft
    
    def make_bow_vector(sentence, word_to_ix):
        vec = torch.zeros(len(word_to_ix))
        for word in sentence:
            vec[word_to_ix[word]] += 1
        return vec.view(1, -1)

    def make_target(label, label_to_ix):
        
        return torch.LongTensor([label_to_ix[label]])

# %% [markdown]
# Ejemplo de BoWClassifier

# %%
## Tomo un tweet
sample = train[0]
print (sample)

## Genera el BowVector, es del largo del diccionario y tiene unos en las posiciones donde las palabras del tweet coinciden con el diccionario
bow_vector = BoWClassifier.make_bow_vector(sample[0], word_to_ix)
print(bow_vector)

## Aplico el modelo y obtengo la probabilidad de que el tweet sea meteorológico o no meteorológico
log_probs = model(bow_vector)
print (log_probs.exp())
# Out:
# (['quiero', 'ir', 'centro', 'mañana', 'pero', 'seguro', 'llueve'], 0)
# tensor([[1., 1., 1.,  ..., 0., 0., 0.]])
# tensor([[0.4968, 0.5032]], grad_fn=<ExpBackward>)

# %% [markdown]
# #### Miremos la frecuencia de ocurrencia de palabras en el diccionario

# %%
vec = torch.zeros(len(word_to_ix))
for i, label in test+train:
    bow_vector = BoWClassifier.make_bow_vector(i, word_to_ix)
    vec = vec.add(bow_vector)

vec=vec[0].tolist()

# %%
## Genero un dataframe que me pemite ordenar de mayor a menor respecto de la columna Frecuencia
tot = pd.DataFrame()
tot['Diccionario'] = list(word_to_ix.keys())
tot['Frecuencia'] = vec
tot['Num'] = word_to_ix.values()
tot = tot.sort_values(by=['Frecuencia'], ascending=False)
# Out:
#         Diccionario  Frecuencia   Num
# 24           lluvia       971.0    24
# 29               no       376.0    29
# 6            llueve       262.0     6
# 79         tormenta       258.0    79
# 7                si       143.0     7
# 42              que       130.0    42
# 203      \U0001f60d       110.0   203
# 4              pero       107.0     4
# 25           viento       103.0    25
# 231          dormir        99.0   231
# 65             todo        97.0    65
# 107             mas        96.0   107
# 229             hoy        89.0   229
# 460             dia        88.0   460
# 13           cuando        78.0    13
# 122              yo        75.0   122
# 363            rayo        73.0   363
# 22              hum        72.0    22
# 305              ya        70.0   305
# 18        tormentas        64.0    18
# 32            ahora        62.0    32
# 37            tengo        62.0    37
# 52           porque        61.0    52
# 726              la        60.0   726
# 139            dias        58.0   139
# 49          lluvias        57.0    49
# 3            mañana        57.0     3
# 43            linda        56.0    43
# 134             sol        55.0   134
# 141             ver        54.0   141
# ...             ...         ...   ...
# 2349     \U0001f38a         1.0  2349
# 2350       ratifica         1.0  2350
# 2351         masiva         1.0  2351
# 2352   convocatoria         1.0  2352
# 2353       desfiles         1.0  2353
# 2354     presentara         1.0  2354
# 2330        amargue         1.0  2330
# 2329        peleada         1.0  2329
# 2328         seguia         1.0  2328
# 2327    bodasoñadas         1.0  2327
# 2302         nantes         1.0  2302
# 2303           liga         1.0  2303
# 2304      vallecano         1.0  2304
# 2305         adrian         1.0  2305
# 2306        embarba         1.0  2306
# 2307          eibar         1.0  2307
# 2308        cardiff         1.0  2308
# 2309           city         1.0  2309
# 2310           aron         1.0  2310
# 2311     gunnarsson         1.0  2311
# 2312         junior         1.0  2312
# 2313        hoilett         1.0  2313
# 2314  wolverhampton         1.0  2314
# 2315           matt         1.0  2315
# 2316        doherty         1.0  2316
# 2319          asoma         1.0  2319
# 2320         nieves         1.0  2320
# 2321            men         1.0  2321
# 2326  celebraciones         1.0  2326
# 4467    situaciones         1.0  4467
#
# [4468 rows x 3 columns]

# %% [markdown]
# #### Probamos la red sin entrenar

# %%
# Run on test data before we train, just to see a before-and-after
for instance, label in test:
    bow_vec = BoWClassifier.make_bow_vector(instance, word_to_ix)
    log_probs = model(bow_vec)
    #print (log_probs.exp(), label)
#print (next(model.parameters())[:,word_to_ix["lluvia"]])
# Out:
# tensor([[0.4740, 0.5260]], grad_fn=<ExpBackward>) 0
# tensor([[0.4865, 0.5135]], grad_fn=<ExpBackward>) 0
# tensor([[0.4874, 0.5126]], grad_fn=<ExpBackward>) 1
# tensor([[0.4786, 0.5214]], grad_fn=<ExpBackward>) 1
# tensor([[0.4846, 0.5154]], grad_fn=<ExpBackward>) 0
# tensor([[0.4866, 0.5134]], grad_fn=<ExpBackward>) 1
# tensor([[0.4836, 0.5164]], grad_fn=<ExpBackward>) 0
# tensor([[0.4843, 0.5157]], grad_fn=<ExpBackward>) 0
# tensor([[0.4795, 0.5205]], grad_fn=<ExpBackward>) 0
# tensor([[0.4869, 0.5131]], grad_fn=<ExpBackward>) 1
# tensor([[0.4901, 0.5099]], grad_fn=<ExpBackward>) 1
# tensor([[0.4904, 0.5096]], grad_fn=<ExpBackward>) 0
# tensor([[0.4714, 0.5286]], grad_fn=<ExpBackward>) 1
# tensor([[0.4837, 0.5163]], grad_fn=<ExpBackward>) 1
# tensor([[0.4880, 0.5120]], grad_fn=<ExpBackward>) 0
# tensor([[0.4912, 0.5088]], grad_fn=<ExpBackward>) 0
# tensor([[0.4779, 0.5221]], grad_fn=<ExpBackward>) 0
# tensor([[0.4753, 0.5247]], grad_fn=<ExpBackward>) 0
# tensor([[0.4829, 0.5171]], grad_fn=<ExpBackward>) 0
# tensor([[0.4925, 0.5075]], grad_fn=<ExpBackward>) 0
# tensor([[0.4814, 0.5186]], grad_fn=<ExpBackward>) 1
# tensor([[0.4616, 0.5384]], grad_fn=<ExpBackward>) 1
# tensor([[0.4870, 0.5130]], grad_fn=<ExpBackward>) 1
# tensor([[0.4874, 0.5126]], grad_fn=<ExpBackward>) 0
# tensor([[0.4909, 0.5091]], grad_fn=<ExpBackward>) 1
# tensor([[0.4830, 0.5170]], grad_fn=<ExpBackward>) 1
# tensor([[0.4906, 0.5094]], grad_fn=<ExpBackward>) 1
# tensor([[0.4914, 0.5086]], grad_fn=<ExpBackward>) 1
# tensor([[0.4815, 0.5185]], grad_fn=<ExpBackward>) 1
# tensor([[0.4887, 0.5113]], grad_fn=<ExpBackward>) 0
# tensor([[0.4938, 0.5062]], grad_fn=<ExpBackward>) 1
# tensor([[0.4840, 0.5160]], grad_fn=<ExpBackward>) 0
# tensor([[0.4798, 0.5202]], grad_fn=<ExpBackward>) 0
# tensor([[0.4870, 0.5130]], grad_fn=<ExpBackward>) 1
# tensor([[0.4855, 0.5145]], grad_fn=<ExpBackward>) 1
# tensor([[0.4841, 0.5159]], grad_fn=<ExpBackward>) 0
# tensor([[0.4863, 0.5137]], grad_fn=<ExpBackward>) 0
# tensor([[0.4834, 0.5166]], grad_fn=<ExpBackward>) 0
# tensor([[0.4827, 0.5173]], grad_fn=<ExpBackward>) 1
# tensor([[0.4816, 0.5184]], grad_fn=<ExpBackward>) 0
# tensor([[0.4861, 0.5139]], grad_fn=<ExpBackward>) 0
# tensor([[0.4911, 0.5089]], grad_fn=<ExpBackward>) 1
# tensor([[0.4810, 0.5190]], grad_fn=<ExpBackward>) 1
# tensor([[0.4892, 0.5108]], grad_fn=<ExpBackward>) 1
# tensor([[0.4836, 0.5164]], grad_fn=<ExpBackward>) 0
# tensor([[0.4864, 0.5136]], grad_fn=<ExpBackward>) 1
# tensor([[0.4853, 0.5147]], grad_fn=<ExpBackward>) 0
# tensor([[0.4826, 0.5174]], grad_fn=<ExpBackward>) 0
# tensor([[0.4881, 0.5119]], grad_fn=<ExpBackward>) 0
# tensor([[0.4842, 0.5158]], grad_fn=<ExpBackward>) 1
# tensor([[0.4744, 0.5256]], grad_fn=<ExpBackward>) 1
# tensor([[0.4880, 0.5120]], grad_fn=<ExpBackward>) 1
# tensor([[0.5008, 0.4992]], grad_fn=<ExpBackward>) 1
# tensor([[0.4890, 0.5110]], grad_fn=<ExpBackward>) 0
# tensor([[0.4875, 0.5125]], grad_fn=<ExpBackward>) 1
# tensor([[0.4903, 0.5097]], grad_fn=<ExpBackward>) 1
# tensor([[0.4788, 0.5212]], grad_fn=<ExpBackward>) 1
# tensor([[0.4818, 0.5182]], grad_fn=<ExpBackward>) 0
# tensor([[0.4907, 0.5093]], grad_fn=<ExpBackward>) 0
# tensor([[0.4891, 0.5109]], grad_fn=<ExpBackward>) 0
# tensor([[0.4887, 0.5113]], grad_fn=<ExpBackward>) 1
# tensor([[0.4870, 0.5130]], grad_fn=<ExpBackward>) 0
# tensor([[0.4780, 0.5220]], grad_fn=<ExpBackward>) 1
# tensor([[0.4823, 0.5177]], grad_fn=<ExpBackward>) 1
# tensor([[0.4793, 0.5207]], grad_fn=<ExpBackward>) 1
# tensor([[0.5023, 0.4977]], grad_fn=<ExpBackward>) 0
# tensor([[0.4830, 0.5170]], grad_fn=<ExpBackward>) 0
# tensor([[0.4887, 0.5113]], grad_fn=<ExpBackward>) 0
# tensor([[0.5072, 0.4928]], grad_fn=<ExpBackward>) 1
# tensor([[0.4845, 0.5155]], grad_fn=<ExpBackward>) 1
# tensor([[0.5065, 0.4935]], grad_fn=<ExpBackward>) 0
# tensor([[0.4876, 0.5124]], grad_fn=<ExpBackward>) 0
# tensor([[0.4774, 0.5226]], grad_fn=<ExpBackward>) 0
# tensor([[0.4924, 0.5076]], grad_fn=<ExpBackward>) 1
# tensor([[0.4817, 0.5183]], grad_fn=<ExpBackward>) 0
# tensor([[0.4951, 0.5049]], grad_fn=<ExpBackward>) 0
# tensor([[0.4987, 0.5013]], grad_fn=<ExpBackward>) 0
# tensor([[0.4870, 0.5130]], grad_fn=<ExpBackward>) 1
# tensor([[0.4983, 0.5017]], grad_fn=<ExpBackward>) 0
# tensor([[0.4854, 0.5146]], grad_fn=<ExpBackward>) 1
# tensor([[0.4823, 0.5177]], grad_fn=<ExpBackward>) 1
# tensor([[0.4895, 0.5105]], grad_fn=<ExpBackward>) 0
# tensor([[0.4844, 0.5156]], grad_fn=<ExpBackward>) 1
# tensor([[0.4995, 0.5005]], grad_fn=<ExpBackward>) 0
# tensor([[0.4862, 0.5138]], grad_fn=<ExpBackward>) 0
# tensor([[0.4894, 0.5106]], grad_fn=<ExpBackward>) 1
# tensor([[0.4873, 0.5127]], grad_fn=<ExpBackward>) 1
# tensor([[0.4915, 0.5085]], grad_fn=<ExpBackward>) 1
# tensor([[0.4743, 0.5257]], grad_fn=<ExpBackward>) 1
# tensor([[0.4836, 0.5164]], grad_fn=<ExpBackward>) 0
# tensor([[0.4951, 0.5049]], grad_fn=<ExpBackward>) 0
# tensor([[0.4811, 0.5189]], grad_fn=<ExpBackward>) 1
# tensor([[0.4857, 0.5143]], grad_fn=<ExpBackward>) 1
# tensor([[0.4802, 0.5198]], grad_fn=<ExpBackward>) 0
# tensor([[0.4835, 0.5165]], grad_fn=<ExpBackward>) 1
# tensor([[0.4890, 0.5110]], grad_fn=<ExpBackward>) 0
# tensor([[0.4975, 0.5025]], grad_fn=<ExpBackward>) 1
# tensor([[0.4886, 0.5114]], grad_fn=<ExpBackward>) 0
# tensor([[0.4987, 0.5013]], grad_fn=<ExpBackward>) 0
# tensor([[0.4929, 0.5071]], grad_fn=<ExpBackward>) 0
# tensor([[0.4879, 0.5121]], grad_fn=<ExpBackward>) 1
# tensor([[0.4887, 0.5113]], grad_fn=<ExpBackward>) 1
# tensor([[0.4877, 0.5123]], grad_fn=<ExpBackward>) 1
# tensor([[0.4871, 0.5129]], grad_fn=<ExpBackward>) 1
# tensor([[0.4905, 0.5095]], grad_fn=<ExpBackward>) 0
# tensor([[0.4837, 0.5163]], grad_fn=<ExpBackward>) 0
# tensor([[0.4830, 0.5170]], grad_fn=<ExpBackward>) 0
# tensor([[0.4858, 0.5142]], grad_fn=<ExpBackward>) 1
# tensor([[0.4899, 0.5101]], grad_fn=<ExpBackward>) 0
# tensor([[0.4851, 0.5149]], grad_fn=<ExpBackward>) 0
# tensor([[0.4853, 0.5147]], grad_fn=<ExpBackward>) 0
# tensor([[0.4922, 0.5078]], grad_fn=<ExpBackward>) 1
# tensor([[0.4884, 0.5116]], grad_fn=<ExpBackward>) 1
# tensor([[0.4900, 0.5100]], grad_fn=<ExpBackward>) 0
# tensor([[0.4900, 0.5100]], grad_fn=<ExpBackward>) 1
# tensor([[0.4942, 0.5058]], grad_fn=<ExpBackward>) 1
# tensor([[0.4766, 0.5234]], grad_fn=<ExpBackward>) 1
# tensor([[0.4841, 0.5159]], grad_fn=<ExpBackward>) 1
# tensor([[0.4802, 0.5198]], grad_fn=<ExpBackward>) 0
# tensor([[0.4852, 0.5148]], grad_fn=<ExpBackward>) 1
# tensor([[0.4780, 0.5220]], grad_fn=<ExpBackward>) 0
# tensor([[0.4675, 0.5325]], grad_fn=<ExpBackward>) 0
# tensor([[0.4843, 0.5157]], grad_fn=<ExpBackward>) 0
# tensor([[0.4842, 0.5158]], grad_fn=<ExpBackward>) 1
# tensor([[0.4842, 0.5158]], grad_fn=<ExpBackward>) 0
# tensor([[0.4832, 0.5168]], grad_fn=<ExpBackward>) 1
# tensor([[0.4855, 0.5145]], grad_fn=<ExpBackward>) 0
# tensor([[0.4816, 0.5184]], grad_fn=<ExpBackward>) 1
# tensor([[0.4861, 0.5139]], grad_fn=<ExpBackward>) 1
# tensor([[0.4954, 0.5046]], grad_fn=<ExpBackward>) 1
# tensor([[0.4808, 0.5192]], grad_fn=<ExpBackward>) 0
# tensor([[0.4841, 0.5159]], grad_fn=<ExpBackward>) 1
# tensor([[0.4908, 0.5092]], grad_fn=<ExpBackward>) 0
# tensor([[0.4874, 0.5126]], grad_fn=<ExpBackward>) 0
# tensor([[0.4890, 0.5110]], grad_fn=<ExpBackward>) 0
# tensor([[0.4804, 0.5196]], grad_fn=<ExpBackward>) 0
# tensor([[0.4804, 0.5196]], grad_fn=<ExpBackward>) 0
# tensor([[0.4906, 0.5094]], grad_fn=<ExpBackward>) 1
# tensor([[0.4832, 0.5168]], grad_fn=<ExpBackward>) 0
# tensor([[0.4806, 0.5194]], grad_fn=<ExpBackward>) 1
# tensor([[0.4833, 0.5167]], grad_fn=<ExpBackward>) 1
# tensor([[0.4996, 0.5004]], grad_fn=<ExpBackward>) 1
# tensor([[0.4827, 0.5173]], grad_fn=<ExpBackward>) 0
# tensor([[0.4890, 0.5110]], grad_fn=<ExpBackward>) 1
# tensor([[0.4836, 0.5164]], grad_fn=<ExpBackward>) 0
# tensor([[0.4869, 0.5131]], grad_fn=<ExpBackward>) 0
# tensor([[0.4954, 0.5046]], grad_fn=<ExpBackward>) 1
# tensor([[0.4816, 0.5184]], grad_fn=<ExpBackward>) 1
# tensor([[0.4864, 0.5136]], grad_fn=<ExpBackward>) 1
# tensor([[0.4802, 0.5198]], grad_fn=<ExpBackward>) 0
# tensor([[0.4931, 0.5069]], grad_fn=<ExpBackward>) 1
# tensor([[0.4847, 0.5153]], grad_fn=<ExpBackward>) 0
# tensor([[0.4867, 0.5133]], grad_fn=<ExpBackward>) 1
# tensor([[0.4939, 0.5061]], grad_fn=<ExpBackward>) 0
# tensor([[0.4862, 0.5138]], grad_fn=<ExpBackward>) 1
# tensor([[0.4822, 0.5178]], grad_fn=<ExpBackward>) 0
# tensor([[0.4893, 0.5107]], grad_fn=<ExpBackward>) 1
# tensor([[0.4864, 0.5136]], grad_fn=<ExpBackward>) 0
# tensor([[0.4854, 0.5146]], grad_fn=<ExpBackward>) 1
# tensor([[0.4866, 0.5134]], grad_fn=<ExpBackward>) 0
# tensor([[0.4839, 0.5161]], grad_fn=<ExpBackward>) 0
# tensor([[0.4909, 0.5091]], grad_fn=<ExpBackward>) 1
# tensor([[0.4828, 0.5172]], grad_fn=<ExpBackward>) 0
# tensor([[0.4804, 0.5196]], grad_fn=<ExpBackward>) 0
# tensor([[0.4879, 0.5121]], grad_fn=<ExpBackward>) 0
# tensor([[0.4926, 0.5074]], grad_fn=<ExpBackward>) 0
# tensor([[0.4852, 0.5148]], grad_fn=<ExpBackward>) 1
# tensor([[0.4892, 0.5108]], grad_fn=<ExpBackward>) 1
# tensor([[0.4856, 0.5144]], grad_fn=<ExpBackward>) 1
# tensor([[0.4799, 0.5201]], grad_fn=<ExpBackward>) 1
# tensor([[0.4767, 0.5233]], grad_fn=<ExpBackward>) 0
# tensor([[0.4756, 0.5244]], grad_fn=<ExpBackward>) 1
# tensor([[0.4931, 0.5069]], grad_fn=<ExpBackward>) 0
# tensor([[0.4814, 0.5186]], grad_fn=<ExpBackward>) 1
# tensor([[0.4893, 0.5107]], grad_fn=<ExpBackward>) 1
# tensor([[0.4838, 0.5162]], grad_fn=<ExpBackward>) 1
# tensor([[0.4875, 0.5125]], grad_fn=<ExpBackward>) 1
# tensor([[0.4877, 0.5123]], grad_fn=<ExpBackward>) 0
# tensor([[0.4935, 0.5065]], grad_fn=<ExpBackward>) 0
# tensor([[0.5203, 0.4797]], grad_fn=<ExpBackward>) 0
# tensor([[0.4920, 0.5080]], grad_fn=<ExpBackward>) 0
# tensor([[0.4845, 0.5155]], grad_fn=<ExpBackward>) 1
# tensor([[0.4831, 0.5169]], grad_fn=<ExpBackward>) 1
# tensor([[0.4912, 0.5088]], grad_fn=<ExpBackward>) 0
# tensor([[0.4881, 0.5119]], grad_fn=<ExpBackward>) 0
# tensor([[0.4827, 0.5173]], grad_fn=<ExpBackward>) 0
# tensor([[0.4922, 0.5078]], grad_fn=<ExpBackward>) 0
# tensor([[0.4726, 0.5274]], grad_fn=<ExpBackward>) 1
# tensor([[0.4843, 0.5157]], grad_fn=<ExpBackward>) 0
# tensor([[0.4819, 0.5181]], grad_fn=<ExpBackward>) 1
# tensor([[0.4874, 0.5126]], grad_fn=<ExpBackward>) 1
# tensor([[0.4799, 0.5201]], grad_fn=<ExpBackward>) 0
# tensor([[0.4873, 0.5127]], grad_fn=<ExpBackward>) 0
# tensor([[0.4686, 0.5314]], grad_fn=<ExpBackward>) 0
# tensor([[0.4818, 0.5182]], grad_fn=<ExpBackward>) 0
# tensor([[0.4812, 0.5188]], grad_fn=<ExpBackward>) 0
# tensor([[0.4754, 0.5246]], grad_fn=<ExpBackward>) 1
# tensor([[0.4856, 0.5144]], grad_fn=<ExpBackward>) 1
# tensor([[0.4983, 0.5017]], grad_fn=<ExpBackward>) 0
# tensor([[0.4915, 0.5085]], grad_fn=<ExpBackward>) 0
# tensor([[0.4875, 0.5125]], grad_fn=<ExpBackward>) 0
# tensor([[0.4894, 0.5106]], grad_fn=<ExpBackward>) 0
# tensor([[0.4794, 0.5206]], grad_fn=<ExpBackward>) 1
# tensor([[0.4954, 0.5046]], grad_fn=<ExpBackward>) 0
# tensor([[0.4863, 0.5137]], grad_fn=<ExpBackward>) 0
# tensor([[0.4849, 0.5151]], grad_fn=<ExpBackward>) 1
# tensor([[0.4926, 0.5074]], grad_fn=<ExpBackward>) 1
# tensor([[0.4835, 0.5165]], grad_fn=<ExpBackward>) 0
# tensor([[0.4808, 0.5192]], grad_fn=<ExpBackward>) 1
# tensor([[0.4829, 0.5171]], grad_fn=<ExpBackward>) 1
# tensor([[0.4833, 0.5167]], grad_fn=<ExpBackward>) 1
# tensor([[0.4852, 0.5148]], grad_fn=<ExpBackward>) 0
# tensor([[0.4799, 0.5201]], grad_fn=<ExpBackward>) 0
# tensor([[0.4850, 0.5150]], grad_fn=<ExpBackward>) 1
# tensor([[0.4875, 0.5125]], grad_fn=<ExpBackward>) 1
# tensor([[0.4903, 0.5097]], grad_fn=<ExpBackward>) 1
# tensor([[0.4834, 0.5166]], grad_fn=<ExpBackward>) 0
# tensor([[0.4824, 0.5176]], grad_fn=<ExpBackward>) 0
# tensor([[0.4830, 0.5170]], grad_fn=<ExpBackward>) 1
# tensor([[0.4866, 0.5134]], grad_fn=<ExpBackward>) 0
# tensor([[0.4885, 0.5115]], grad_fn=<ExpBackward>) 1
# tensor([[0.4853, 0.5147]], grad_fn=<ExpBackward>) 0
# tensor([[0.4876, 0.5124]], grad_fn=<ExpBackward>) 0
# tensor([[0.5010, 0.4990]], grad_fn=<ExpBackward>) 0
# tensor([[0.4847, 0.5153]], grad_fn=<ExpBackward>) 0
# tensor([[0.4857, 0.5143]], grad_fn=<ExpBackward>) 0
# tensor([[0.4881, 0.5119]], grad_fn=<ExpBackward>) 0
# tensor([[0.4858, 0.5142]], grad_fn=<ExpBackward>) 0
# tensor([[0.4856, 0.5144]], grad_fn=<ExpBackward>) 0
# tensor([[0.4832, 0.5168]], grad_fn=<ExpBackward>) 1
# tensor([[0.4856, 0.5144]], grad_fn=<ExpBackward>) 1
# tensor([[0.4838, 0.5162]], grad_fn=<ExpBackward>) 0
# tensor([[0.4718, 0.5282]], grad_fn=<ExpBackward>) 1
# tensor([[0.4839, 0.5161]], grad_fn=<ExpBackward>) 0
# tensor([[0.4883, 0.5117]], grad_fn=<ExpBackward>) 1
# tensor([[0.4837, 0.5163]], grad_fn=<ExpBackward>) 0
# tensor([[0.4888, 0.5112]], grad_fn=<ExpBackward>) 1
# tensor([[0.4856, 0.5144]], grad_fn=<ExpBackward>) 0
# tensor([[0.4923, 0.5077]], grad_fn=<ExpBackward>) 1
# tensor([[0.4805, 0.5195]], grad_fn=<ExpBackward>) 0
# tensor([[0.4842, 0.5158]], grad_fn=<ExpBackward>) 0
# tensor([[0.4827, 0.5173]], grad_fn=<ExpBackward>) 0
# tensor([[0.4782, 0.5218]], grad_fn=<ExpBackward>) 1
# tensor([[0.4886, 0.5114]], grad_fn=<ExpBackward>) 0
# tensor([[0.4799, 0.5201]], grad_fn=<ExpBackward>) 0
# tensor([[0.4913, 0.5087]], grad_fn=<ExpBackward>) 1
# tensor([[0.4847, 0.5153]], grad_fn=<ExpBackward>) 1
# tensor([[0.4837, 0.5163]], grad_fn=<ExpBackward>) 0
# tensor([[0.4744, 0.5256]], grad_fn=<ExpBackward>) 1
# tensor([[0.4806, 0.5194]], grad_fn=<ExpBackward>) 0
# tensor([[0.4890, 0.5110]], grad_fn=<ExpBackward>) 1
# tensor([[0.4758, 0.5242]], grad_fn=<ExpBackward>) 1
# tensor([[0.4790, 0.5210]], grad_fn=<ExpBackward>) 0
# tensor([[0.4892, 0.5108]], grad_fn=<ExpBackward>) 0
# tensor([[0.4839, 0.5161]], grad_fn=<ExpBackward>) 0
# tensor([[0.4832, 0.5168]], grad_fn=<ExpBackward>) 0
# tensor([[0.4869, 0.5131]], grad_fn=<ExpBackward>) 1
# tensor([[0.4806, 0.5194]], grad_fn=<ExpBackward>) 1
# tensor([[0.4963, 0.5037]], grad_fn=<ExpBackward>) 0
# tensor([[0.4704, 0.5296]], grad_fn=<ExpBackward>) 1
# tensor([[0.4763, 0.5237]], grad_fn=<ExpBackward>) 1
# tensor([[0.4868, 0.5132]], grad_fn=<ExpBackward>) 1
# tensor([[0.4881, 0.5119]], grad_fn=<ExpBackward>) 1
# tensor([[0.4770, 0.5230]], grad_fn=<ExpBackward>) 0
# tensor([[0.5034, 0.4966]], grad_fn=<ExpBackward>) 0
# tensor([[0.4898, 0.5102]], grad_fn=<ExpBackward>) 1
# tensor([[0.4821, 0.5179]], grad_fn=<ExpBackward>) 1
# tensor([[0.4812, 0.5188]], grad_fn=<ExpBackward>) 0
# tensor([[0.4880, 0.5120]], grad_fn=<ExpBackward>) 1
# tensor([[0.4798, 0.5202]], grad_fn=<ExpBackward>) 0
# tensor([[0.4860, 0.5140]], grad_fn=<ExpBackward>) 0
# tensor([[0.4807, 0.5193]], grad_fn=<ExpBackward>) 0
# tensor([[0.4843, 0.5157]], grad_fn=<ExpBackward>) 0
# tensor([[0.4919, 0.5081]], grad_fn=<ExpBackward>) 0
# tensor([[0.4753, 0.5247]], grad_fn=<ExpBackward>) 1
# tensor([[0.4919, 0.5081]], grad_fn=<ExpBackward>) 1
# tensor([[0.4799, 0.5201]], grad_fn=<ExpBackward>) 1
# tensor([[0.4872, 0.5128]], grad_fn=<ExpBackward>) 1
# tensor([[0.4794, 0.5206]], grad_fn=<ExpBackward>) 1
# tensor([[0.4892, 0.5108]], grad_fn=<ExpBackward>) 1
# tensor([[0.4843, 0.5157]], grad_fn=<ExpBackward>) 0
# tensor([[0.4839, 0.5161]], grad_fn=<ExpBackward>) 0
# tensor([[0.4887, 0.5113]], grad_fn=<ExpBackward>) 1
# tensor([[0.4825, 0.5175]], grad_fn=<ExpBackward>) 0
# tensor([[0.4865, 0.5135]], grad_fn=<ExpBackward>) 0
# tensor([[0.4803, 0.5197]], grad_fn=<ExpBackward>) 1
# tensor([[0.4866, 0.5134]], grad_fn=<ExpBackward>) 0
# tensor([[0.4854, 0.5146]], grad_fn=<ExpBackward>) 0
# tensor([[0.4915, 0.5085]], grad_fn=<ExpBackward>) 1
# tensor([[0.4841, 0.5159]], grad_fn=<ExpBackward>) 1
# tensor([[0.4912, 0.5088]], grad_fn=<ExpBackward>) 0
# tensor([[0.4868, 0.5132]], grad_fn=<ExpBackward>) 0
# tensor([[0.4932, 0.5068]], grad_fn=<ExpBackward>) 1
# tensor([[0.4860, 0.5140]], grad_fn=<ExpBackward>) 0
# tensor([[0.4875, 0.5125]], grad_fn=<ExpBackward>) 1
# tensor([[0.4838, 0.5162]], grad_fn=<ExpBackward>) 0
# tensor([[0.4834, 0.5166]], grad_fn=<ExpBackward>) 1
# tensor([[0.4835, 0.5165]], grad_fn=<ExpBackward>) 1
# tensor([[0.4855, 0.5145]], grad_fn=<ExpBackward>) 1
# tensor([[0.4853, 0.5147]], grad_fn=<ExpBackward>) 1
# tensor([[0.4813, 0.5187]], grad_fn=<ExpBackward>) 1
# tensor([[0.4778, 0.5222]], grad_fn=<ExpBackward>) 0
# tensor([[0.4841, 0.5159]], grad_fn=<ExpBackward>) 1
# tensor([[0.4811, 0.5189]], grad_fn=<ExpBackward>) 1
# tensor([[0.4857, 0.5143]], grad_fn=<ExpBackward>) 1
# tensor([[0.4839, 0.5161]], grad_fn=<ExpBackward>) 0
# tensor([[0.4885, 0.5115]], grad_fn=<ExpBackward>) 1
# tensor([[0.4811, 0.5189]], grad_fn=<ExpBackward>) 0
# tensor([[0.4867, 0.5133]], grad_fn=<ExpBackward>) 1
# tensor([[0.4869, 0.5131]], grad_fn=<ExpBackward>) 0
# tensor([[0.4863, 0.5137]], grad_fn=<ExpBackward>) 1
# tensor([[0.4741, 0.5259]], grad_fn=<ExpBackward>) 1
# tensor([[0.4779, 0.5221]], grad_fn=<ExpBackward>) 1
# tensor([[0.4865, 0.5135]], grad_fn=<ExpBackward>) 1
# tensor([[0.4886, 0.5114]], grad_fn=<ExpBackward>) 0
# tensor([[0.4696, 0.5304]], grad_fn=<ExpBackward>) 0
# tensor([[0.4792, 0.5208]], grad_fn=<ExpBackward>) 0
# tensor([[0.4827, 0.5173]], grad_fn=<ExpBackward>) 1
# tensor([[0.4836, 0.5164]], grad_fn=<ExpBackward>) 1
# tensor([[0.4898, 0.5102]], grad_fn=<ExpBackward>) 1
# tensor([[0.4772, 0.5228]], grad_fn=<ExpBackward>) 0
# tensor([[0.4869, 0.5131]], grad_fn=<ExpBackward>) 0
# tensor([[0.4862, 0.5138]], grad_fn=<ExpBackward>) 1
# tensor([[0.4866, 0.5134]], grad_fn=<ExpBackward>) 0
# tensor([[0.4838, 0.5162]], grad_fn=<ExpBackward>) 0
# tensor([[0.4833, 0.5167]], grad_fn=<ExpBackward>) 0
# tensor([[0.4741, 0.5259]], grad_fn=<ExpBackward>) 0
# tensor([[0.4821, 0.5179]], grad_fn=<ExpBackward>) 1
# tensor([[0.4802, 0.5198]], grad_fn=<ExpBackward>) 1
# tensor([[0.4876, 0.5124]], grad_fn=<ExpBackward>) 1
# tensor([[0.4935, 0.5065]], grad_fn=<ExpBackward>) 1
# tensor([[0.4800, 0.5200]], grad_fn=<ExpBackward>) 1
# tensor([[0.4810, 0.5190]], grad_fn=<ExpBackward>) 0
# tensor([[0.4909, 0.5091]], grad_fn=<ExpBackward>) 1
# tensor([[0.4849, 0.5151]], grad_fn=<ExpBackward>) 0
# tensor([[0.4780, 0.5220]], grad_fn=<ExpBackward>) 1
# tensor([[0.4870, 0.5130]], grad_fn=<ExpBackward>) 1
# tensor([[0.4876, 0.5124]], grad_fn=<ExpBackward>) 0
# tensor([[0.4837, 0.5163]], grad_fn=<ExpBackward>) 1
# tensor([[0.4845, 0.5155]], grad_fn=<ExpBackward>) 1
# tensor([[0.4887, 0.5113]], grad_fn=<ExpBackward>) 0
# tensor([[0.4939, 0.5061]], grad_fn=<ExpBackward>) 1
# tensor([[0.4833, 0.5167]], grad_fn=<ExpBackward>) 1
# tensor([[0.4862, 0.5138]], grad_fn=<ExpBackward>) 1
# tensor([[0.4839, 0.5161]], grad_fn=<ExpBackward>) 1
# tensor([[0.4698, 0.5302]], grad_fn=<ExpBackward>) 1
# tensor([[0.4806, 0.5194]], grad_fn=<ExpBackward>) 1
# tensor([[0.4872, 0.5128]], grad_fn=<ExpBackward>) 0
# tensor([[0.4822, 0.5178]], grad_fn=<ExpBackward>) 1
# tensor([[0.4882, 0.5118]], grad_fn=<ExpBackward>) 1
# tensor([[0.4923, 0.5077]], grad_fn=<ExpBackward>) 1
# tensor([[0.4844, 0.5156]], grad_fn=<ExpBackward>) 1
# tensor([[0.4889, 0.5111]], grad_fn=<ExpBackward>) 1
# tensor([-3.0732e-03,  4.6536e-03, -1.4074e-02, -1.1961e-02,  1.0582e-02,
#          5.4382e-03,  1.4667e-02, -2.2990e-03, -1.4360e-02, -6.3226e-03,
#         -9.3395e-03,  4.9897e-04, -1.3065e-02, -1.3181e-02, -2.3238e-03,
#         -1.3366e-02, -1.4947e-03,  6.0999e-03, -5.5823e-03, -4.9935e-03,
#          1.4552e-02, -1.1717e-02,  2.7405e-03,  9.0824e-03,  4.8477e-05,
#          1.0201e-02, -5.1740e-03,  5.7959e-03,  1.4383e-03, -1.2393e-02,
#          8.0990e-03,  4.9822e-03,  3.6465e-03, -9.9740e-03,  1.1476e-02,
#          1.6361e-03,  1.3931e-02,  9.0761e-03,  2.1968e-03,  1.1785e-02,
#          8.3060e-03, -9.0676e-03, -8.7760e-03,  1.4198e-02,  1.3833e-02,
#          1.9710e-03,  4.1252e-03, -3.8361e-03, -1.2859e-02,  8.9655e-03,
#          1.0901e-02,  1.0932e-02,  8.8155e-03, -1.2096e-02,  9.7420e-03,
#         -1.8848e-03, -1.0011e-02,  7.3232e-03,  1.1005e-02,  8.4744e-03,
#          2.9280e-03, -2.6623e-03, -9.1339e-03, -5.2797e-03, -7.1105e-03,
#         -6.1844e-03,  1.0677e-02,  8.2549e-03, -8.3083e-04, -1.6244e-03,
#          4.3288e-03, -1.2057e-02,  5.3310e-03,  9.4101e-03,  1.1541e-03,
#         -6.5718e-03,  1.1192e-02, -1.3700e-02, -2.9725e-03,  1.0676e-02,
#         -1.4885e-02,  1.4850e-02, -1.1829e-02,  1.2857e-02, -4.4073e-04,
#         -1.1574e-02,  1.3453e-02,  2.4431e-03,  7.8601e-05, -1.6995e-03,
#          8.9797e-03,  1.1103e-02,  1.0765e-02, -7.1366e-03,  1.3338e-02,
#          4.0291e-03, -2.0736e-03,  7.6126e-03,  1.5335e-03, -1.2862e-02],
#        grad_fn=<SelectBackward>)

# %% [markdown]
# ### Entrenamiento

# %%
model = BoWClassifier(NUM_LABELS, VOCAB_SIZE)
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Se suele usar la cantidad de epocas que lleve a la estabilidad sin overfitear

error = []

for epoch in range(50):
    if epoch % 10 == 0: print('Epoch: %i' %epoch)
    for instance, label in train:
        
        
        # Hay que resetear los gradientes antes de hacer cuentas
        model.zero_grad()
    
        # Hacemos el vector de bag of words
        bow_vec = BoWClassifier.make_bow_vector(instance, word_to_ix)
        
        # Guardamos el label del diccionario de Tags
        target = BoWClassifier.make_target(label, label_to_ix)
    
        # Hacemos el forward pass.
        log_probs = model(bow_vec)
    
        # Calculamos el error
        loss = loss_function(log_probs, target)
    
        # Le pedimos a torch que busque los gradientes con back propagation
        
        loss.backward()
        
        # Usamos SGD para hacer back propagation y modificar los pesos
        optimizer.step()
    error.append(loss) 

   
plt.figure()
plt.plot(error)
plt.show()
# Out:
# Epoch: 0
# Epoch: 10
# Epoch: 20
# Epoch: 30
# Epoch: 40

# %% [markdown]
# ## Usamos los twits de test para verificar

# %%
c = [0,0,0,0]
for instance, label in test:
    bow_vec = autograd.Variable(BoWClassifier.make_bow_vector(instance, word_to_ix))
    log_probs = model(bow_vec)
    log_probs_exp = log_probs.exp()
    if bool (log_probs_exp[0][0]>0.5):
        
        if label == 1: 
            c[0]+=1
           # print ('\033[1;93m' , log_probs_exp , label)
        else: 
            c[2]+=1
           # print ('\033[1;31m' , log_probs_exp , label)

    elif bool (log_probs_exp[0][1]>0.5):
        
        if label == 0:
            c[1]+=1
           # print ('\033[1;32m' , log_probs_exp , label)
            
        else:
            c[3]+=1
           # print ('\033[1;66m' , log_probs_exp , label)


print('\033[0m Aciertos a tweets meteorológicos:', round((c[0]/sum(c))*100, 3),
      '% \n Aciertos a tweets no meteorologicos:', round((c[1]/sum(c))*100, 3),
      '% \n Sorpresas: ', round((c[3]/sum(c))*100, 3),
      '% \n Falsos positivos: ', round((c[2]/sum(c))*100, 3), '%') 
print(c)
#print ('\033[0m', next(model.parameters())[:,word_to_ix["lluvia"]]) # Index corresponding to Spanish goes up, English goes down!
# Out:
#  Aciertos a tweets meteorológicos: 29.462 %
#  Aciertos a tweets no meteorologicos: 31.445 %
#  Sorpresas:  21.53 %
#  Falsos positivos:  17.564 %
# [104, 111, 62, 76]

# %% [markdown]
# ## Graficos de verificación

# %%
fig = plt.figure(figsize=(13,5))



opacity = 0.4
bar_width = 0.35


"""GRAFICO DE VERIFICACIÓN"""

ax = plt.subplot(1,2,1)

bar = plt.bar(range(4),c,
              tick_label=['Aciertos \n Meteorológico','Aciertos No \n Meteorológico',
                          'Falsos positivos','Sorpresas'], color = 'skyblue')
plt.title('Resultados')
plt.ylabel('Cantidad de aciertos.  Total='+str(sum(c)))
for rect, porcentaje in zip(bar,c):
    height = rect.get_height()- 5
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % round((porcentaje/sum(c))*100, 3) + ' %'
             ,fontsize = 13, color = 'black',ha='center', va='bottom')

  
"""GRÁFICO DE COMPARACIÓN PARA CADA TAG"""
    
ax2 = plt.subplot(1,2,2)

bar1 = plt.bar(np.arange(2), [c[0]+c[2],cant[1]+c[3]], bar_width, 
               tick_label = ['Meteorológicos', 'No Meteorológicos'],
               color = 'skyblue', label = 'Total de twits'
              )

for rect, porcentaje in zip(bar1,[c[0]+c[2],c[1]+c[3]]):
    height = rect.get_height()-20
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % porcentaje
             ,fontsize = 13, color = 'black',ha='center', va='bottom')


bar2 = plt.bar(np.arange(2) +bar_width, [c[3],c[2]], bar_width,
              tick_label = ['Meteorológicos', 'No Meteorológicos'],
               color = 'salmon' , label= 'Total de Fallas'
              )
for rect, porcentaje in zip(bar2,[c[3],c[2]]):
    height = rect.get_height()-20
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % porcentaje
             ,fontsize = 13, color = 'black',ha='center', va='bottom')

plt.legend()
plt.title('Comparativa')
# Out:
# Text(0.5, 1.0, 'Comparativa')
