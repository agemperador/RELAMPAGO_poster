# %% [markdown]
# # Detección de tweets meteorológicos con Bag of Words

# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Cargo la base de datos clasificada y genero las variables de importancia

# %%
TW = pd.read_csv('base_corr_ortografia.csv')
MSJ = TW['Twit']
TAG = TW['Tag']
NUM = TW['Num']

# %% [markdown]
# ### Defino una variable cantidad que tiene la cantidad de tw de cada tipo

# %%
cant = [len (np.array(TAG) [np.where(TAG == 0)]) , len (np.array(TAG) [np.where(TAG == 1)])]

# %% [markdown]
# #### Elimino las cosas innecesarias de msj

# %%
def normalizacion(mensaje):
    
    mensaje = list(mensaje)
    lenght = len(mensaje)
    
    lista_ascii = [['\\xe1', '\\xe9', '\\xed', '\\xf3', '\\xfa', '\\xf1', '\\xd1', '\\xc1','\\xc9', '\\xcd', '\\xd3', 
                 '\\xda', '\\xa1', '\\xbf', '\\xdc', '\\xfc', '\\xb4', '\\xba', '\\xaa', '\\xb7','\\xc7','\\xe7',
                 '\\xa8', '\\xb0C', '\\n', '\\xb0c', '\\xbb', 'xb0', '\\ufe0f'],['a', 'e', 'i', 'o', 'u', 'ñ', 'Ñ', 'A', 'E', 'I', 'O', 'U', '', '', 'Ü', 'ü', '', 
                           ' ', '', '','Ç','ç','', ' ', ' ', ' ', ' ', ' ', ' ']]
    lista_simb = ['!','\'', '\"', "|", '$', "%", "&", "(", ")", "=", "?", "+",'/', ";", "_", "-", "1","2","3","4","5","6","7","8","9","0", '*',',', '.', ':', '#']
    
    ign_palabras = ['mbar','cdu','s','la','lo','st','que','este', 'me','t','p','el','weathercloud','en','h','temp','hpa','km','mm',"su","vos",'que',"re","xq","le","te","tu","soy","sos","mi","da","o","x","les","me","d","q", "como", "lo", "los", "mi", "son", "a", "el", 
                    "un","la", "una","en","por","para", 'las',"ante", "al", 'me',"rt", "del", "y", "se", "de", "que", "sus", "ha", "es", "con", "esta"]
    
    for i in range(lenght):
        
        ## Convierto mayúsculas en minúsculas
        mensaje[i] = mensaje[i].lower()
        
        ## Saco las menciones y otras cosas
        txt = mensaje[i].split()
        
        for j in range(len(txt)):
            if ('@' in txt[j]) and ('RELAMPAGO2018' not in txt[j]) and ('RELAMPAGO_edu' not in txt[j]) or ('jaj' in txt[j]) or ('https' in txt[j]): txt[j]=''
        
        mensaje[i] = " ".join(txt)
        
        ## Reemplazo símbolos
        for h in range(len(lista_simb)):
            mensaje[i] = mensaje[i].replace(lista_simb[h], ' ')
            
        ## Convierto el msj a ASCII, reemplazo los errores de decodificación y agrego un espacio antes de cada decodificación
        mensaje[i] = mensaje[i].encode('unicode-escape').decode('ASCII')+" "     
        
        for j in range(len(lista_ascii[0])):
            mensaje[i] = mensaje[i].replace(lista_ascii[0][j], lista_ascii[1][j])
        
        mensaje[i] = mensaje[i].replace('\\', ' \\')
        
        for j in range(len(ign_palabras)):
            mensaje[i] = mensaje[i].replace(" "+ign_palabras[j]+" ", ' ')
        
    return(mensaje)
msj = normalizacion(MSJ)

# %% [markdown]
# #### División en datasets de  _train_ y _test_

# %%
size = 0.8

## Toma los tweets, los asocia con su tag y luego los divide en cada una de las palabras que los componen
## zip() itera tuplas

train = [(i.split(),j) for i,j in zip(list(msj)[1:int(len(msj)*0.8)],list(TAG)[1:int(len(msj)*0.8)])]

test = [(i.split(),j) for i,j in zip(list(msj)[int(len(msj)*0.8)+1:len(msj)],list(TAG)[int(len(msj)*0.8)+1:len(msj)])]

## Guardo los labels, (en este caso 1 y 0) en un diccionario
label_to_ix = { 1: 0, 0: 1 } 

# 1 = Meteorológico
# 0 = No meteorológico

# %% [markdown]
# #### Generación del diccionario con el dataset completo

# %%
word_to_ix = {}

# El diccionario tiene que tener todas las palabras posibles
datos = train + test

## Cada palabra que encuentra la guarda en un diccionario
for sent, _ in datos:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

VOCAB_SIZE = len(word_to_ix)
NUM_LABELS = 2

# %% [markdown]
# #### Bag of Words

# %%
class BoWClassifier(nn.Module): # inheriting from nn.Module!
    
    def __init__(self, num_labels, vocab_size):
        
        super(BoWClassifier, self).__init__()

        self.linear1 = nn.Linear(vocab_size, 200)
        self.linear2 = nn.Linear(200, num_labels)
        
        
    def forward(self, bow_vec):
        
        h = self.linear1(bow_vec)
        
        y = self.linear2(h)
        
        soft = F.log_softmax(y , dim=1)
        
        return soft
    
    def make_bow_vector(sentence, word_to_ix):
        vec = torch.zeros(len(word_to_ix))
        for word in sentence:
            vec[word_to_ix[word]] += 1
        return vec.view(1, -1)

    def make_target(label, label_to_ix):
        
        return torch.LongTensor([label_to_ix[label]])
    
model = BoWClassifier(NUM_LABELS, VOCAB_SIZE)

# %% [markdown]
# Ejemplo de BoWClassifier

# %%
## Tomo un tweet
sample = train[0]
print (sample)

## Genera el BowVector, es del largo del diccionario y tiene unos en las posiciones donde las palabras del tweet coinciden con el diccionario
bow_vector = BoWClassifier.make_bow_vector(sample[0], word_to_ix)
print(bow_vector)

## Aplico el modelo y obtengo la probabilidad de que el tweet sea meteorológico o no meteorológico
log_probs = model(bow_vector)
print (log_probs.exp())
# Out:
# (['quiero', 'ir', 'centro', 'mañana', 'pero', 'seguro', 'llueve'], 0)
# tensor([[1., 1., 1.,  ..., 0., 0., 0.]])
# tensor([[0.5095, 0.4905]], grad_fn=<ExpBackward>)

# %% [markdown]
# #### Miremos la frecuencia de ocurrencia de palabras en el diccionario

# %%
vec = torch.zeros(len(word_to_ix))
for i, label in test+train:
    bow_vector = BoWClassifier.make_bow_vector(i, word_to_ix)
    vec = vec.add(bow_vector)

vec=vec[0].tolist()

# %%
## Genero un dataframe que me pemite ordenar de mayor a menor respecto de la columna Frecuencia
tot = pd.DataFrame()
tot['Diccionario'] = list(word_to_ix.keys())
tot['Frecuencia'] = vec
tot['Num'] = word_to_ix.values()
tot = tot.sort_values(by=['Frecuencia'], ascending=False)
tot
# Out:
#                Diccionario  Frecuencia   Num
# 24                  lluvia       520.0    24
# 29                      no       186.0    29
# 6                   llueve       152.0     6
# 79                tormenta       126.0    79
# 7                       si        71.0     7
# 42                     que        71.0    42
# 203             \U0001f60d        71.0   203
# 25                  viento        57.0    25
# 231                 dormir        55.0   231
# 4                     pero        54.0     4
# 107                    mas        53.0   107
# 229                    hoy        52.0   229
# 65                    todo        47.0    65
# 458                    dia        46.0   458
# 13                  cuando        44.0    13
# 18               tormentas        39.0    18
# 22                     hum        39.0    22
# 122                     yo        38.0   122
# 304                     ya        37.0   304
# 32                   ahora        36.0    32
# 267                  lindo        35.0   267
# 37                   tengo        34.0    37
# 362                   rayo        34.0   362
# 99                   estoy        33.0    99
# 134                    sol        33.0   134
# 3                   mañana        32.0     3
# 563                  rayos        32.0   563
# 139                   dias        32.0   139
# 141                    ver        31.0   141
# 227                 barrio        30.0   227
# ...                    ...         ...   ...
# 1340              cantando         1.0  1340
# 1341            intentamos         1.0  1341
# 1362                truene         1.0  1362
# 1386           bendiciones         1.0  1386
# 1385                  lili         1.0  1385
# 1380              volverme         1.0  1380
# 1378                 birra         1.0  1378
# 1377              complica         1.0  1377
# 1376              moderada         1.0  1376
# 1373                  napa         1.0  1373
# 1372                 subio         1.0  1372
# 1371               empieza         1.0  1371
# 1370                  alla         1.0  1370
# 1368                  cana         1.0  1368
# 1364                    az         1.0  1364
# 1361              seguimos         1.0  1361
# 1342                dilema         1.0  1342
# 1360                guapos         1.0  1360
# 1359        felicitaciones         1.0  1359
# 1358         entrenamiento         1.0  1358
# 1357               detenga         1.0  1357
# 1354  supermercadoslareina         1.0  1354
# 1353           auspiciadas         1.0  1353
# 1352               calidad         1.0  1352
# 1351              variedad         1.0  1351
# 1350                 aldia         1.0  1350
# 1349                ponete         1.0  1349
# 1345              comienza         1.0  1345
# 1343            mondaymood         1.0  1343
# 2809            \U0001f622         1.0  2809
#
# [2810 rows x 3 columns]

# %% [markdown]
# #### Probamos la red sin entrenar

# %%
# Run on test data before we train, just to see a before-and-after
for instance, label in test:
    bow_vec = BoWClassifier.make_bow_vector(instance, word_to_ix)
    log_probs = model(bow_vec)
    print (log_probs.exp(), label)
print (next(model.parameters())[:,word_to_ix["lluvia"]])
# Out:
# tensor([[0.5017, 0.4983]], grad_fn=<ExpBackward>) 1
# tensor([[0.5224, 0.4776]], grad_fn=<ExpBackward>) 1
# tensor([[0.5013, 0.4987]], grad_fn=<ExpBackward>) 0
# tensor([[0.5209, 0.4791]], grad_fn=<ExpBackward>) 1
# tensor([[0.5132, 0.4868]], grad_fn=<ExpBackward>) 0
# tensor([[0.5119, 0.4881]], grad_fn=<ExpBackward>) 1
# tensor([[0.5228, 0.4772]], grad_fn=<ExpBackward>) 1
# tensor([[0.4880, 0.5120]], grad_fn=<ExpBackward>) 1
# tensor([[0.5188, 0.4812]], grad_fn=<ExpBackward>) 1
# tensor([[0.5164, 0.4836]], grad_fn=<ExpBackward>) 1
# tensor([[0.5174, 0.4826]], grad_fn=<ExpBackward>) 1
# tensor([[0.4943, 0.5057]], grad_fn=<ExpBackward>) 1
# tensor([[0.5245, 0.4755]], grad_fn=<ExpBackward>) 1
# tensor([[0.4867, 0.5133]], grad_fn=<ExpBackward>) 1
# tensor([[0.5058, 0.4942]], grad_fn=<ExpBackward>) 0
# tensor([[0.5133, 0.4867]], grad_fn=<ExpBackward>) 0
# tensor([[0.5035, 0.4965]], grad_fn=<ExpBackward>) 0
# tensor([[0.5080, 0.4920]], grad_fn=<ExpBackward>) 0
# tensor([[0.5125, 0.4875]], grad_fn=<ExpBackward>) 0
# tensor([[0.5244, 0.4756]], grad_fn=<ExpBackward>) 0
# tensor([[0.5176, 0.4824]], grad_fn=<ExpBackward>) 0
# tensor([[0.5220, 0.4780]], grad_fn=<ExpBackward>) 0
# tensor([[0.5080, 0.4920]], grad_fn=<ExpBackward>) 1
# tensor([[0.5007, 0.4993]], grad_fn=<ExpBackward>) 0
# tensor([[0.5193, 0.4807]], grad_fn=<ExpBackward>) 0
# tensor([[0.5178, 0.4822]], grad_fn=<ExpBackward>) 0
# tensor([[0.5070, 0.4930]], grad_fn=<ExpBackward>) 1
# tensor([[0.5057, 0.4943]], grad_fn=<ExpBackward>) 0
# tensor([[0.5118, 0.4882]], grad_fn=<ExpBackward>) 1
# tensor([[0.5044, 0.4956]], grad_fn=<ExpBackward>) 0
# tensor([[0.5153, 0.4847]], grad_fn=<ExpBackward>) 0
# tensor([[0.4980, 0.5020]], grad_fn=<ExpBackward>) 0
# tensor([[0.5133, 0.4867]], grad_fn=<ExpBackward>) 0
# tensor([[0.5189, 0.4811]], grad_fn=<ExpBackward>) 0
# tensor([[0.4994, 0.5006]], grad_fn=<ExpBackward>) 1
# tensor([[0.5069, 0.4931]], grad_fn=<ExpBackward>) 1
# tensor([[0.5150, 0.4850]], grad_fn=<ExpBackward>) 0
# tensor([[0.5118, 0.4882]], grad_fn=<ExpBackward>) 0
# tensor([[0.5136, 0.4864]], grad_fn=<ExpBackward>) 0
# tensor([[0.5154, 0.4846]], grad_fn=<ExpBackward>) 1
# tensor([[0.5231, 0.4769]], grad_fn=<ExpBackward>) 0
# tensor([[0.5034, 0.4966]], grad_fn=<ExpBackward>) 0
# tensor([[0.4972, 0.5028]], grad_fn=<ExpBackward>) 0
# tensor([[0.5057, 0.4943]], grad_fn=<ExpBackward>) 0
# tensor([[0.5093, 0.4907]], grad_fn=<ExpBackward>) 0
# tensor([[0.5181, 0.4819]], grad_fn=<ExpBackward>) 0
# tensor([[0.5029, 0.4971]], grad_fn=<ExpBackward>) 1
# tensor([[0.4948, 0.5052]], grad_fn=<ExpBackward>) 0
# tensor([[0.4721, 0.5279]], grad_fn=<ExpBackward>) 0
# tensor([[0.5169, 0.4831]], grad_fn=<ExpBackward>) 0
# tensor([[0.5072, 0.4928]], grad_fn=<ExpBackward>) 1
# tensor([[0.5018, 0.4982]], grad_fn=<ExpBackward>) 1
# tensor([[0.4872, 0.5128]], grad_fn=<ExpBackward>) 0
# tensor([[0.5084, 0.4916]], grad_fn=<ExpBackward>) 0
# tensor([[0.5045, 0.4955]], grad_fn=<ExpBackward>) 0
# tensor([[0.5070, 0.4930]], grad_fn=<ExpBackward>) 1
# tensor([[0.5124, 0.4876]], grad_fn=<ExpBackward>) 1
# tensor([[0.4999, 0.5001]], grad_fn=<ExpBackward>) 0
# tensor([[0.5032, 0.4968]], grad_fn=<ExpBackward>) 0
# tensor([[0.5133, 0.4867]], grad_fn=<ExpBackward>) 0
# tensor([[0.5022, 0.4978]], grad_fn=<ExpBackward>) 0
# tensor([[0.4815, 0.5185]], grad_fn=<ExpBackward>) 0
# tensor([[0.5246, 0.4754]], grad_fn=<ExpBackward>) 0
# tensor([[0.5018, 0.4982]], grad_fn=<ExpBackward>) 0
# tensor([[0.5064, 0.4936]], grad_fn=<ExpBackward>) 0
# tensor([[0.5088, 0.4912]], grad_fn=<ExpBackward>) 0
# tensor([[0.5032, 0.4968]], grad_fn=<ExpBackward>) 1
# tensor([[0.4896, 0.5104]], grad_fn=<ExpBackward>) 0
# tensor([[0.5176, 0.4824]], grad_fn=<ExpBackward>) 0
# tensor([[0.5011, 0.4989]], grad_fn=<ExpBackward>) 0
# tensor([[0.5134, 0.4866]], grad_fn=<ExpBackward>) 0
# tensor([[0.4888, 0.5112]], grad_fn=<ExpBackward>) 1
# tensor([[0.5145, 0.4855]], grad_fn=<ExpBackward>) 1
# tensor([[0.5008, 0.4992]], grad_fn=<ExpBackward>) 1
# tensor([[0.4949, 0.5051]], grad_fn=<ExpBackward>) 0
# tensor([[0.5111, 0.4889]], grad_fn=<ExpBackward>) 1
# tensor([[0.5159, 0.4841]], grad_fn=<ExpBackward>) 0
# tensor([[0.5118, 0.4882]], grad_fn=<ExpBackward>) 0
# tensor([[0.5165, 0.4835]], grad_fn=<ExpBackward>) 0
# tensor([[0.5013, 0.4987]], grad_fn=<ExpBackward>) 0
# tensor([[0.5247, 0.4753]], grad_fn=<ExpBackward>) 0
# tensor([[0.5071, 0.4929]], grad_fn=<ExpBackward>) 1
# tensor([[0.4790, 0.5210]], grad_fn=<ExpBackward>) 0
# tensor([[0.5151, 0.4849]], grad_fn=<ExpBackward>) 0
# tensor([[0.5077, 0.4923]], grad_fn=<ExpBackward>) 1
# tensor([[0.4989, 0.5011]], grad_fn=<ExpBackward>) 1
# tensor([[0.5217, 0.4783]], grad_fn=<ExpBackward>) 0
# tensor([[0.4996, 0.5004]], grad_fn=<ExpBackward>) 0
# tensor([[0.4866, 0.5134]], grad_fn=<ExpBackward>) 0
# tensor([[0.5067, 0.4933]], grad_fn=<ExpBackward>) 1
# tensor([[0.5141, 0.4859]], grad_fn=<ExpBackward>) 0
# tensor([[0.5113, 0.4887]], grad_fn=<ExpBackward>) 0
# tensor([[0.5462, 0.4538]], grad_fn=<ExpBackward>) 0
# tensor([[0.5161, 0.4839]], grad_fn=<ExpBackward>) 0
# tensor([[0.5191, 0.4809]], grad_fn=<ExpBackward>) 0
# tensor([[0.4988, 0.5012]], grad_fn=<ExpBackward>) 0
# tensor([[0.5088, 0.4912]], grad_fn=<ExpBackward>) 1
# tensor([[0.5046, 0.4954]], grad_fn=<ExpBackward>) 0
# tensor([[0.5006, 0.4994]], grad_fn=<ExpBackward>) 1
# tensor([[0.5182, 0.4818]], grad_fn=<ExpBackward>) 0
# tensor([[0.5078, 0.4922]], grad_fn=<ExpBackward>) 1
# tensor([[0.5097, 0.4903]], grad_fn=<ExpBackward>) 0
# tensor([[0.5142, 0.4858]], grad_fn=<ExpBackward>) 1
# tensor([[0.5168, 0.4832]], grad_fn=<ExpBackward>) 0
# tensor([[0.5046, 0.4954]], grad_fn=<ExpBackward>) 1
# tensor([[0.5118, 0.4882]], grad_fn=<ExpBackward>) 1
# tensor([[0.4879, 0.5121]], grad_fn=<ExpBackward>) 0
# tensor([[0.4971, 0.5029]], grad_fn=<ExpBackward>) 1
# tensor([[0.4980, 0.5020]], grad_fn=<ExpBackward>) 0
# tensor([[0.5110, 0.4890]], grad_fn=<ExpBackward>) 1
# tensor([[0.5103, 0.4897]], grad_fn=<ExpBackward>) 0
# tensor([[0.4977, 0.5023]], grad_fn=<ExpBackward>) 0
# tensor([[0.5125, 0.4875]], grad_fn=<ExpBackward>) 0
# tensor([[0.5014, 0.4986]], grad_fn=<ExpBackward>) 0
# tensor([[0.4903, 0.5097]], grad_fn=<ExpBackward>) 1
# tensor([[0.5058, 0.4942]], grad_fn=<ExpBackward>) 1
# tensor([[0.4977, 0.5023]], grad_fn=<ExpBackward>) 0
# tensor([[0.5029, 0.4971]], grad_fn=<ExpBackward>) 1
# tensor([[0.5176, 0.4824]], grad_fn=<ExpBackward>) 0
# tensor([[0.4863, 0.5137]], grad_fn=<ExpBackward>) 1
# tensor([[0.4965, 0.5035]], grad_fn=<ExpBackward>) 0
# tensor([[0.5051, 0.4949]], grad_fn=<ExpBackward>) 0
# tensor([[0.4702, 0.5298]], grad_fn=<ExpBackward>) 1
# tensor([[0.5135, 0.4865]], grad_fn=<ExpBackward>) 1
# tensor([[0.5047, 0.4953]], grad_fn=<ExpBackward>) 1
# tensor([[0.5088, 0.4912]], grad_fn=<ExpBackward>) 0
# tensor([[0.5025, 0.4975]], grad_fn=<ExpBackward>) 1
# tensor([[0.5110, 0.4890]], grad_fn=<ExpBackward>) 0
# tensor([[0.5214, 0.4786]], grad_fn=<ExpBackward>) 1
# tensor([[0.5122, 0.4878]], grad_fn=<ExpBackward>) 1
# tensor([[0.4993, 0.5007]], grad_fn=<ExpBackward>) 0
# tensor([[0.5048, 0.4952]], grad_fn=<ExpBackward>) 1
# tensor([[0.5125, 0.4875]], grad_fn=<ExpBackward>) 0
# tensor([[0.5021, 0.4979]], grad_fn=<ExpBackward>) 1
# tensor([[0.5054, 0.4946]], grad_fn=<ExpBackward>) 1
# tensor([[0.4940, 0.5060]], grad_fn=<ExpBackward>) 1
# tensor([[0.4993, 0.5007]], grad_fn=<ExpBackward>) 1
# tensor([[0.5027, 0.4973]], grad_fn=<ExpBackward>) 0
# tensor([[0.5062, 0.4938]], grad_fn=<ExpBackward>) 0
# tensor([[0.5089, 0.4911]], grad_fn=<ExpBackward>) 0
# tensor([[0.5012, 0.4988]], grad_fn=<ExpBackward>) 0
# tensor([[0.4680, 0.5320]], grad_fn=<ExpBackward>) 0
# tensor([[0.4902, 0.5098]], grad_fn=<ExpBackward>) 1
# tensor([[0.4961, 0.5039]], grad_fn=<ExpBackward>) 0
# tensor([[0.5149, 0.4851]], grad_fn=<ExpBackward>) 1
# tensor([[0.5078, 0.4922]], grad_fn=<ExpBackward>) 0
# tensor([[0.5011, 0.4989]], grad_fn=<ExpBackward>) 0
# tensor([[0.5209, 0.4791]], grad_fn=<ExpBackward>) 1
# tensor([[0.5076, 0.4924]], grad_fn=<ExpBackward>) 1
# tensor([[0.5025, 0.4975]], grad_fn=<ExpBackward>) 1
# tensor([[0.5063, 0.4937]], grad_fn=<ExpBackward>) 1
# tensor([[0.5092, 0.4908]], grad_fn=<ExpBackward>) 0
# tensor([[0.5149, 0.4851]], grad_fn=<ExpBackward>) 1
# tensor([[0.4991, 0.5009]], grad_fn=<ExpBackward>) 0
# tensor([[0.4816, 0.5184]], grad_fn=<ExpBackward>) 1
# tensor([[0.5079, 0.4921]], grad_fn=<ExpBackward>) 1
# tensor([[0.5074, 0.4926]], grad_fn=<ExpBackward>) 1
# tensor([[0.5049, 0.4951]], grad_fn=<ExpBackward>) 0
# tensor([[0.5297, 0.4703]], grad_fn=<ExpBackward>) 0
# tensor([[0.5078, 0.4922]], grad_fn=<ExpBackward>) 0
# tensor([[0.5047, 0.4953]], grad_fn=<ExpBackward>) 0
# tensor([[0.5102, 0.4898]], grad_fn=<ExpBackward>) 1
# tensor([[0.5099, 0.4901]], grad_fn=<ExpBackward>) 0
# tensor([[0.5163, 0.4837]], grad_fn=<ExpBackward>) 0
# tensor([[0.5065, 0.4935]], grad_fn=<ExpBackward>) 0
# tensor([[0.5256, 0.4744]], grad_fn=<ExpBackward>) 0
# tensor([[0.4959, 0.5041]], grad_fn=<ExpBackward>) 1
# tensor([[0.4874, 0.5126]], grad_fn=<ExpBackward>) 1
# tensor([[0.5140, 0.4860]], grad_fn=<ExpBackward>) 1
# tensor([[0.5071, 0.4929]], grad_fn=<ExpBackward>) 1
# tensor([[0.5140, 0.4860]], grad_fn=<ExpBackward>) 0
# tensor([[0.5022, 0.4978]], grad_fn=<ExpBackward>) 0
# tensor([[0.4978, 0.5022]], grad_fn=<ExpBackward>) 0
# tensor([[0.5120, 0.4880]], grad_fn=<ExpBackward>) 1
# tensor([[0.5155, 0.4845]], grad_fn=<ExpBackward>) 0
# tensor([[0.5204, 0.4796]], grad_fn=<ExpBackward>) 1
# tensor([[0.5176, 0.4824]], grad_fn=<ExpBackward>) 1
# tensor([[0.5035, 0.4965]], grad_fn=<ExpBackward>) 1
# tensor([[0.5129, 0.4871]], grad_fn=<ExpBackward>) 1
# tensor([[0.5107, 0.4893]], grad_fn=<ExpBackward>) 0
# tensor([[0.5066, 0.4934]], grad_fn=<ExpBackward>) 1
# tensor([[0.4978, 0.5022]], grad_fn=<ExpBackward>) 1
# tensor([[0.5246, 0.4754]], grad_fn=<ExpBackward>) 1
# tensor([[0.4915, 0.5085]], grad_fn=<ExpBackward>) 1
# tensor([[0.5149, 0.4851]], grad_fn=<ExpBackward>) 0
# tensor([[0.5083, 0.4917]], grad_fn=<ExpBackward>) 1
# tensor([[0.4954, 0.5046]], grad_fn=<ExpBackward>) 1
# tensor([ 0.0050, -0.0177], grad_fn=<SelectBackward>)

# %% [markdown]
# ### Entrenamiento

# %%
loss_function = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.1)

# Se suele usar la cantidad de epocas que lleve a la estabilidad sin overfitear

error = []

for epoch in range(50):
    if epoch % 10 == 0: print('Epoch: %i' %epoch)
    for instance, label in train:
        
        
        # Hay que resetear los gradientes antes de hacer cuentas
        model.zero_grad()
    
        # Hacemos el vector de bag of words
        bow_vec = BoWClassifier.make_bow_vector(instance, word_to_ix)
        
        # Guardamos el label del diccionario de Tags
        target = BoWClassifier.make_target(label, label_to_ix)
    
        # Hacemos el forward pass.
        log_probs = model(bow_vec)
    
        # Calculamos el error
        loss = loss_function(log_probs, target)
        
        # Le pedimos a torch que busque los gradientes con back propagation
        loss.backward()
        
        # Usamos SGD para hacer back propagation y modificar los pesos
        optimizer.step()
        
    error.append(loss)
  
plt.figure()
plt.plot(error)
plt.show()
# Out:
# Epoch: 0
# Epoch: 0
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Epoch: 7
# Epoch: 8
# Epoch: 9
# Epoch: 10
# Epoch: 11
# Epoch: 12
# Epoch: 13
# Epoch: 14
# Epoch: 15
# Epoch: 16
# Epoch: 17
# Epoch: 18
# Epoch: 19
# Epoch: 20
# Epoch: 21
# Epoch: 22
# Epoch: 23
# Epoch: 24
# Epoch: 25
# Epoch: 26
# Epoch: 27
# Epoch: 28
# Epoch: 29
# Epoch: 30
# Epoch: 31
# Epoch: 32
# Epoch: 33
# Epoch: 34
# Epoch: 35
# Epoch: 36
# Epoch: 37
# Epoch: 38
# Epoch: 39
# Epoch: 40
# Epoch: 41
# Epoch: 42
# Epoch: 43
# Epoch: 44
# Epoch: 45
# Epoch: 46
# Epoch: 47
# Epoch: 48
# Epoch: 49

# %% [markdown]
# ## Usamos los twits de test para verificar

# %%
c = [0,0,0,0]
for instance, label in test:
    bow_vec = autograd.Variable(BoWClassifier.make_bow_vector(instance, word_to_ix))
    log_probs = model(bow_vec)
    log_probs_exp = log_probs.exp()
    if bool (log_probs_exp[0][0]>0.5):
        
        if label == 1: 
            c[0]+=1
           # print ('\033[1;93m' , log_probs_exp , label)
        else: 
            c[2]+=1
           # print ('\033[1;31m' , log_probs_exp , label)

    elif bool (log_probs_exp[0][1]>0.5):
        
        if label == 0:
            c[1]+=1
           # print ('\033[1;32m' , log_probs_exp , label)
            
        else:
            c[3]+=1
           # print ('\033[1;66m' , log_probs_exp , label)


print('\033[0m Aciertos a tweets meteorológicos:', round((c[0]/sum(c))*100, 3),
      '% \n Aciertos a tweets no meteorologicos:', round((c[1]/sum(c))*100, 3),
      '% \n Sorpresas: ', round((c[3]/sum(c))*100, 3),
      '% \n Falsos positivos: ', round((c[2]/sum(c))*100, 3), '%') 
print(c)
#print ('\033[0m', next(model.parameters())[:,word_to_ix["lluvia"]]) # Index corresponding to Spanish goes up, English goes down!
# Out:
#  Aciertos a tweets meteorológicos: 28.342 %
#  Aciertos a tweets no meteorologicos: 37.433 %
#  Sorpresas:  14.973 %
#  Falsos positivos:  19.251 %
# [53, 70, 36, 28]

# %% [markdown]
# ## Graficos de verificación

# %%
fig = plt.figure(figsize=(13,5))



opacity = 0.4
bar_width = 0.35


"""GRAFICO DE VERIFICACIÓN"""

ax = plt.subplot(1,2,1)

bar = plt.bar(range(4),c,
              tick_label=['Aciertos \n Meteorológico','Aciertos No \n Meteorológico',
                          'Falsos positivos','Sorpresas'], color = 'skyblue')
plt.title('Resultados')
plt.ylabel('Cantidad de aciertos.  Total='+str(sum(c)))
for rect, porcentaje in zip(bar,c):
    height = rect.get_height()- 5
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % round((porcentaje/sum(c))*100, 3) + ' %'
             ,fontsize = 13, color = 'black',ha='center', va='bottom')

  
"""GRÁFICO DE COMPARACIÓN PARA CADA TAG"""
    
ax2 = plt.subplot(1,2,2)

bar1 = plt.bar(np.arange(2), [c[0]+c[2],cant[1]+c[3]], bar_width, 
               tick_label = ['Meteorológicos', 'No Meteorológicos'],
               color = 'skyblue', label = 'Total de twits'
              )

for rect, porcentaje in zip(bar1,[c[0]+c[2],c[1]+c[3]]):
    height = rect.get_height()-20
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % porcentaje
             ,fontsize = 13, color = 'black',ha='center', va='bottom')


bar2 = plt.bar(np.arange(2) +bar_width, [c[3],c[2]], bar_width,
              tick_label = ['Meteorológicos', 'No Meteorológicos'],
               color = 'salmon' , label= 'Total de Fallas'
              )
for rect, porcentaje in zip(bar2,[c[3],c[2]]):
    height = rect.get_height()-20
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % porcentaje
             ,fontsize = 13, color = 'black',ha='center', va='bottom')

plt.legend()
plt.title('Comparativa')
# Out:
# Text(0.5, 1.0, 'Comparativa')
